# %%
def read_captions(file_location):
  image_caption_list={}
  with open(file_location,"r") as file_obj:
    for data in file_obj.readlines():
      splitted_data=data.strip().split("\t")
      image_name=splitted_data[0][:-2]
      image_caption=splitted_data[1]
      if image_name not in image_caption_list:
        image_caption_list[image_name]=[]
      image_caption_list[image_name].append(image_caption)
  return image_caption_list

# %%
def map_image_captions(file_location,image_caption_list):
  image_caption_mapping={}
  with open(file_location,"r") as file_obj:
    for img_name in file_obj.readlines():
      image_name=img_name.strip()
      if image_name in image_caption_list:
        image_caption_mapping[image_name]=image_caption_list[image_name]
      else:
        print(image_name)
  return image_caption_mapping

# %%
image_caption_file_location="/content/drive/MyDrive/Colab Notebooks/Image Captioning/Flickr8k_text/Flickr8k.lemma.token.txt"
image_caption_list=read_captions(image_caption_file_location)

# %%
train_image_name_file_location="/content/drive/MyDrive/Colab Notebooks/Image Captioning/Flickr8k_text/Flickr_8k.trainImages.txt"
test_image_name_file_location="/content/drive/MyDrive/Colab Notebooks/Image Captioning/Flickr8k_text/Flickr_8k.testImages.txt"
train_image_caption_mapping=map_image_captions(train_image_name_file_location,image_caption_list)
test_image_caption_mapping=map_image_captions(test_image_name_file_location,image_caption_list)

# %%
image_caption_list
# Out:
# {'1305564994_00513f9a5b.jpg': ["A man in street racer armor be examine the tire of another racer 's motorbike .",
#   'Two racer drive a white bike down a road .',
#   'Two motorist be ride along on their vehicle that be oddly design and color .',
#   'Two person be in a small race car drive by a green hill .',
#   'Two person in race uniform in a street car .'],
#  '1351764581_4d4fb1b40f.jpg': ['A firefighter extinguish a fire under the hood of a car .',
#   'a fireman spray water into the hood of small white car on a jack',
#   'A fireman spray inside the open hood of small white car , on a jack .',
#   'A fireman use a firehose on a car engine that be up on a carjack .',
#   'Firefighter use water to extinguish a car that be on fire .'],
#  '1358089136_976e3d2e30.jpg': ['A boy sand surf down a hill',
#   'A man be attempt to surf down a hill make of sand on a sunny day .',
#   'A man be slide down a huge sand dune on a sunny day .',
#   'A man be surf down a hill of sand .',
#   'A young man in short and t-shirt be snowboard under a bright blue sky .'],
#  '1362128028_8422d53dc4.jpg': ['kid play in a blue tub full of water outside',
#   'On a hot day , three small kid sit in a big container fill with water .',
#   'Little kid sit outdoors in a small tub of water .',
#   'Three child squeeze into a plastic tub fill with water and play .',
#   'Three little boy take a bath in a rubber bin on the grass .'],
#  '1383698008_8ac53ed7ec.jpg': ['A man be snowboard over a structure on a snowy hill .',
#   'A snowboarder jump through the air on a snowy hill .',
#   'a snowboarder wear green pants do a trick on a high bench',
#   'Someone in yellow pants be on a ramp over the snow .',
#   'A man be perform a trick on a snowboard high in the air .'],
#  '1468103286_96a6e07029.jpg': ['A Baseball batter raise his arm .',
#   'A baseball player from New York wait to bat during a game .',
#   'A baseball player in a Yankee uniform be hold a bat in one hand',
#   'A New York Yankee hold up a bat .',
#   'New York Yankee warm up .'],
#  '1478268555_7e301fc510.jpg': ['A bare backed climber be attach to the rock face on a pink safety rope .',
#   'a lone rock climber in a harness climb a huge rock wall .',
#   'A man be rock crawl up a rock wall',
#   'A man wear no shirt climb a steep cliff .',
#   'man with no shirt on climb rock'],
#  '161669933_3e7d8c7e2c.jpg': ['A competitive motorcycle racer prepare to make a left turn along a paved road .',
#   'A man ride a motorcycle with the number 5 on it .',
#   'A motorcycle driver swerve to the left .',
#   'A motorcycle with number five on front be be ride by a rider wear a red helmet .',
#   'professional motorcycle racer turn a corner'],
#  '166321294_4a5e68535f.jpg': ['A man be ride on a red motorcycle .',
#   'A motorcycle driver dress in orange gear swerve to the right .',
#   'A motorcyclist on a red speed bike lean into a sharp turn .',
#   'Motorcyclist crouch low as he round a turn .',
#   'This person be on a red motorcycle .'],
#  '166433861_70b66cd381.jpg': ['A motorcycle racer lean his bike .',
#   'A motorcyclist be drive down a road on their motorbike .',
#   'A motorcyclist be ride their sponsored car along a roadway that have recently turn .',
#   'A motorcyclist on a street .',
#   'A motorcyclist with a red helmet ride his blue motorcycle down a road .'],
#  '166507476_9be5b9852a.jpg': ['Iguana wrestle along a rocky water bank .',
#   'Two reptile be stand on their back leg near deep water .',
#   'Two lizard fight .',
#   'Two lizard fight in the water .',
#   'Two oriental lizard be fight for dominance in a small pond'],
#  '1991806812_065f747689.jpg': ['a boxer punch a boxer in the face .',
#   'A fighter attempt to kick another fighter while the other fighter block his kick .',
#   'a kickboxer jump for a kick',
#   'Two boxer be in a ring .',
#   'Two man kickbox in a ring , one man punch the other .'],
#  '2003663004_5b70920a98.jpg': ['A football player pause during a game .',
#   'A football player wear a green jersey with the number " 4 " on it .',
#   'Greenbay football player be be hand a towel on the field .',
#   'Green Bay Packer player cool off',
#   'Someone take a cloth off of a Green Bay Packer football player .'],
#  '2043427251_83b746da8e.jpg': ['a man jump in a mud puddle in the middle of a street',
#   'A man jump up and down in a puddle in a park lot .',
#   'A smile person wear a jacket and boot jump in a big puddle .',
#   'Man jump for joy in a rain storm at a beach .',
#   'Person in blue coat jump in stand water on pavement with body of water in the background .'],
#  '2065309381_705b774f51.jpg': ['A man snowboard down a mountain cover with snow .',
#   'A skier rapidly descend a steep snow cover hill .',
#   'A snowboarder coast down the side of a snowy hill .',
#   'Snowboarder go down a fresh hill .',
#   'The sun be shine above the snow and tree .'],
#  '2073105823_6dacade004.jpg': ['A man in a black hoodie and jean skateboard down a railing .',
#   'A man skateboard down a steep railing next to some step .',
#   'a person be slide down a brick rail on a snowboard .',
#   'A person walk down the brick railing near a set of step .',
#   'A snowboarder ride down a handrail without snow .'],
#  '2100816230_ff866fb352.jpg': ['A man in yellow jump with his ski .',
#   'A man in yellow ski jump over a barrel .',
#   'A man jump while snow ski .',
#   'A skier catch air over the snow .',
#   'Man ski over a barrel in a snowy area .'],
#  '2101128963_fdf8b2a0d7.jpg': ['A baseball be recoil from an action take on a treated field watch by others .',
#   'A baseball player on a play field spring into action .',
#   'A baseball player stand on a mound .',
#   'A Philadelphia Phillie pitcher on a pitcher mound with his left leg up behind him .',
#   'A pitcher in a red and white uniform in a baseball game have just throw the ball .'],
#  '2109911919_af45b93ef3.jpg': ['A person climb up a snowy mountain .',
#   'A person climb up the side of a snowy mountain to fetch his or her ski pole .',
#   'A skier climb up a snowy trail toward his pole .',
#   'A climber with a backpack accends a snow cover mountain .',
#   'Man climb a steep snow-covered slope .'],
#  '2113530024_5bc6a90e42.jpg': ['A goalie try to catch a ball during a soccer game .',
#   'A group of guy play soccer on a field .',
#   'Footballer be scramble around the goal as a goal keeper reach for the ball .',
#   'Four man in green at a soccer goal post try to score , while 3 man in blue try to prevent it .',
#   'Two soccer team converge at the goal and the goalie reach for the ball .'],
#  '2157173498_2eea42ee38.jpg': ['A man be snowboard and jump off of a snow hill .',
#   'A person in a black jacket be snowboard during the even .',
#   'A silhouette of a person snowboard through a pile of snow .',
#   'A snowboarder fly off a snow drift with a colorful sky in the background .',
#   'A person in a parka be on a snowboard .'],
#  '2165677531_e1d5e086f7.jpg': ['A blue rally car pull away from spectator watch from the side of a track .',
#   'A car be be drive on a trail while person on both side of a road look on .',
#   'A race car zoom while onlooker watch .',
#   'A race car go through a dirt course while fan watch .',
#   'Blue race car ride on dirt path with onlooker .'],
#  '2193980605_4221c6474d.jpg': ['A group of person be jump into the air with their arm hold high .',
#   'A group of person in a desert jump , one throw a ball .',
#   'A group of six person have jump into the air in the middle of nowhere and one be catch a ball .',
#   'Six person be jump in the air , one of them throw a ball .',
#   'Six person jump for ball .'],
#  '2198511848_311d8a8c2f.jpg': ['A man jump off a ramp on a snowboard .',
#   'A snowboarder high in the air .',
#   'A snowboarder jump through the air on their snowboard .',
#   'Snowboarder fly off of snowy jump , mountain in background .',
#   'A snowboarder be in the middle of a very tall jump'],
#  '2244613488_4d1f9edb33.jpg': ['Four bicyclist ride along a dirt road between two wire fence .',
#   'Four cyclist on a country trail be pass by an electricity pylon .',
#   'Four bicyclist be ride through the desert .',
#   'three biker bike across the dry land .',
#   'Three cyclist ride near mountain .'],
#  '2269021076_cefc9af989.jpg': ['a girl wear a pink scarf and pink bellbottoms ride her bike outside .',
#   'A woman wear a pink boa ride a bicycle down a pedestrian bridge .',
#   'A woman with pink bag ride her bike over a bridge .',
#   'A woman with silver pants and pink bellbottoms , and a pink scarf ride her bike by a fence , with building in the background .',
#   'A lady with a pink scarf ride her bike over a bridge .'],
#  '2269795781_46a296aa21.jpg': ['A person hit a ball with a tennis racket .',
#   'A person swing at a tennis ball .',
#   'a tennis player wear a green shirt about to hit a ball with his racquet .',
#   'A woman in a green shirt and blue hat be play tennis .',
#   'Miami tennis player hit the ball with a forehand .'],
#  '2285152690_3fb93f65f1.jpg': ['A basketball player in a duke uniform look up .',
#   'There be three basketball player',
#   'Three man in basketball uniform look at something .',
#   'Two basketball player from duke be look upward .',
#   'Two basketball player watch the ball .'],
#  '2289068031_fe26990183.jpg': ['A motocross rider ride in the air over a bar .',
#   'A motorbike jump a pole .',
#   'A person be jump a motorcycle over a pole while camera man film .',
#   'A professional dirt biker do stunt while be videotape',
#   'Man on a motorcycle perform a trick high in the air .'],
#  '2306674172_dc07c7f847.jpg': ['A boy in a blue shirt jump down stair on a skateboard .',
#   'A man fly through the air on his skateboard above a white staircase .',
#   'A skateboarder jump his board down a flight of stair .',
#   'A skateboarder sail over white step .',
#   'Skateboarder jump down stair of building .'],
#  '2308108566_2cba6bca53.jpg': ['A man ride a bike on a dirt path .',
#   'A person bike through the wood .',
#   'A person dirtbikes along a muddy trail .',
#   'Dirt bike rider ride down a slope .',
#   'Person ride a dirt bike down a dirt hill .'],
#  '2332540384_4cf26406a9.jpg': ['A man with an Afro be skate on a vert ramp',
#   'a skateboarder do a trick on a ramp',
#   'A skateboard ride up a ramp and do a trick in midair .',
#   'A skateboarder be perform a trick off a ramp .',
#   'A skateboarder launch off a quarter pipe .'],
#  '2393924525_1bf45ca217.jpg': ['A furocious female tennis player about to hit a tennis ball in the air .',
#   'A woman dress in a blue tennis outfit be return a hit with her tennis racket',
#   'A woman in blue hit a tennis ball in a tennis match .',
#   'A woman play tennis .',
#   'Woman play tennis and hit the ball .'],
#  '2396025708_e4a72e2558.jpg': ['A man parasails in the wave ,',
#   'A man ride large wave on a wind sail .',
#   'A man windsurf in the ocean .',
#   'A person parasails on the crest of a wave .',
#   'A windsurfer in the wave of the ocean .'],
#  '2425262733_afe0718276.jpg': ['A kid wear a brown hoodie do an ollie .',
#   'A man in a hoodie skateboard in front of a blue sky and building , shot from below .',
#   'A skateboarder jump midair near a building .',
#   'A skateboarder make a jump .',
#   'Man with jean and a hood do skateboard trick .'],
#  '2439813616_c9ac54cc9f.jpg': ['A boy skateboard up a concrete ramp .',
#   'A man do trick on his skateboard off a ramp .',
#   'A skateboarder wear a red plaid shirt do a trick off of a concrete ramp .',
#   'its a distorted lens ( almost fish eye ) of a teenage boy skateboard on a concrete block .',
#   'Skateboard rider balance on a rock on his skateboard .'],
#  '2449446913_28fa5b7c75.jpg': ['A group of baseball player wear blue uniform walk across the grass .',
#   "A man 's baseball team leave the field",
#   'A team of baseball player in blue uniform , walk together on field .',
#   'Group of person on a ball team wear blue and white uniform some of glove on their hand one be wear red shoe , tall tree be in the background .',
#   'Twelve member of a baseball team walk across the diamond .'],
#  '2472980433_210ec62874.jpg': ['a man do trick on a motorcycle',
#   'A man put his motorcycle up on its rear wheel on a track .',
#   'A man ride a motorcycle be perform a trick at a track .',
#   'A man stand on his motorcycle while do a wheelie .',
#   'A motorcycle be be ride on a track whilst pull a wheelie .'],
#  '2473737724_355599a263.jpg': ['child be practice judo on red and white mat .',
#   'Girl do martial art on a red mat .',
#   'People practice martial art in a train hall .',
#   'Two child perform a karate move on a red mat .',
#   'Two girl karate fight'],
#  '2489602993_896c1ea40a.jpg': ['A man on a motorcycle go around a corner .',
#   'a man ride a green motorcycle around a corner',
#   'A man with a blue helmet lean into a sharp turn on his motorcycle .',
#   'A motorcyclist on a number 52 bike lean in for a sharp turn .',
#   'The number 52 motorcyclist in a blue and black helmet be go around a corner .'],
#  '2496236371_61dec88113.jpg': ['A man on a motorcycle do a wheelie on a track .',
#   'A man on a red crotch rocket .',
#   'A motorcycle rider do a wheelie .',
#   'Someone in a red and white uniform be drive a red and white motorcycle down a track with the front wheel in the air .',
#   'A red motorcycle pull a wheelie on a racetrack .'],
#  '2512683710_991c9d466d.jpg': ['A boat sail past the rise sun .',
#   'A sailboat in the water .',
#   'A sailboat in the water at sunrise .',
#   'A ship sail in a blue sea .',
#   'An old look ship be sail at sunset'],
#  '2520909293_9bb7f7364e.jpg': ['A guy in a yellow shirt with a bike get very high in the air .',
#   "A man in midair hold his bike 's handlebar",
#   'A man be perform a trick high in the air with a bicycle .',
#   'A man wear a yellow shirt be do a trick high in the air with his bike .',
#   'Man hold onto bike handlebar while in midair .'],
#  '2521213787_ca9b5a1758.jpg': ['A blue car drive down a mostly dirt road .',
#   'A blue race car on an off road track',
#   'Blue car on a small road with man in the background and a res car on a slightly high road .',
#   'Blue race car drive down narrow road',
#   'Bright blue car go down a dirt road , as onlooker watch .'],
#  '2521938720_911ac092f7.jpg': ['A cricketer be lay on the ground between the wicket and the ball .',
#   'A man be lie on the ground , laugh , during a ball game .',
#   'A man play cricket closely inspect a shot .',
#   'Guy play cricket lie on the grass',
#   'A cricket player just miss catch the ball .'],
#  '2521938802_853224f378.jpg': ['A cricket batsman swing',
#   'A man play cricket',
#   'A man wear a baseball uniform swing back with a large bat .',
#   'A man wear white clothes play cricket .',
#   'A baseball player hold up his bat ready to swing .'],
#  '2522540026_6ee8ab4c6a.jpg': ['A race car move down a road as two person watch from a distance .',
#   'A race car , number 104 be round a bend as two person watch and take picture .',
#   'A silver and blue rally car be pass two spectator who be stand at a roadside .',
#   'Blue and silver car go around curve be watch by person stand in grass',
#   'Silver and blue car mark 104 raise dust on road as two background person watch .'],
#  '2524084967_a5e011b73d.jpg': ['A cyclist be perform a jump next to a black advertise banner .',
#   'A male do a bicycle trick in midair .',
#   'A man in a white t-shirt jump something on his yellow bike .',
#   'A trick cyclist take air .',
#   'A man be perform a trick off a ramp with a bicycle .'],
#  '2527713011_b0ec25aa54.jpg': ['A black and white rally car take a turn .',
#   'A global group race car .',
#   'A black and white race car be go fast around a track while fan watch nearby .',
#   'A black and white race car be round a turn .',
#   'A race car be speed up a hill .'],
#  '2528521798_fb689eba8d.jpg': ['A white car race in the dirt and water',
#   'A white race car drive through a puddle .',
#   'A white race car make a splash through a wet track .',
#   'A white race car splash through a puddle on a dirt road',
#   'A white rally car be throw mud into the air as it approach a bend in a track .'],
#  '2528547068_7d37479b9b.jpg': ['A race car drive through a dirt-covered racetrack .',
#   'A red car emit smoke while on a paved track .',
#   'A red race car pull off a track smoke .',
#   'A red race car travel down a road mark with red and white striped ribbon .',
#   'A red rally car take a slippery turn in a race .'],
#  '2528552898_9e49a7033f.jpg': ['A yellow car be drive away from the water .',
#   'A yellow race car be drive on a track in front of a group of person .',
#   'A yellow race car be drive through water on a race course .',
#   'A yellow race car slide through a corner as spectator watch .',
#   'A yellow race car in a curve , with smoke behind it .'],
#  '2529116152_4331dabf50.jpg': ['A darked skinned male be stand on one palm in front of a yellow building .',
#   'a man break dance .',
#   'A man hold himself with one arm i front of a store .',
#   'A young man jump on a table .',
#   'This black man appear to be break dance on the pavement .'],
#  '2529205842_bdcb49d65b.jpg': ['Basketball player have fall on the court while another grab at the ball from out of frame .',
#   'Two basketball player be scramble for the ball on the court .',
#   'Two basketball player , one on the floor , struggle to gain possession of a basketball .',
#   'Two high school basketball player reach to grab the ball , one fall to the floor .',
#   'Two man in uniform play basketball , struggle for the ball .'],
#  '2533414541_362bf043bb.jpg': ['a lone blue and white race car about to cross the finish line',
#   'A race car be observe by a crowd .',
#   'A white and blue car be on a street .',
#   'Spectator watch white and blue race car pass by .',
#   'A blue and white car be in a road , with onlooker nearby .'],
#  '2533424347_cf2f84872b.jpg': ['A race car blow smoke while it drive .',
#   'A race car drive on a track while several person watch from behind rope .',
#   'A race car screech through a turn as spectator watch .',
#   'A sponsored race car be spin its tire on a track while be watch by spectator .',
#   'Onlooker watch a white stock car that have smoke come out of the back .'],
#  '2540360421_f7c2401da8.jpg': ['A male topless rock climber be climb a rock face whilst attach to a safety harness .',
#   'A man without a shirt climb a rock wall with help from a red rope .',
#   'A shirtless man rock climb .',
#   'Shirtless man climb a steep rock face .',
#   'A man in board short be rock climb with a red rope .'],
#  '2546959333_23b957988f.jpg': ['a dog nip at the feet of a cow .',
#   'a dog pounce on the grass .',
#   'A dog be run after a bull .',
#   'A large brown dog be play in the grass with a brown cow .',
#   'Two dog outside on green grass .'],
#  '2554531876_5d7f193992.jpg': ['A motorcycle race .',
#   'A motorcycle rider in a white helmet lean into a curve on a rural road .',
#   'A motorcycle rider make a turn .',
#   'Someone on a motorcycle lean into a turn .',
#   'There be a professional motorcyclist turn a corner .'],
#  '2555521861_fc36fd3ab0.jpg': ['A girl hold onto a rope above the water .',
#   'A girl wear a harness be lift out of the water .',
#   'A person attach to a harness be be drag through the water .',
#   'A person in a harness be hang above water make a spray with their feet .',
#   'A person on a pulley be drag across water .'],
#  '2562483332_eb791a3ce5.jpg': ['A teenage girl and little girl play on pink toy .',
#   'A woman and a girl be swing on a red swing',
#   'A woman play with play equipment while a child look on .',
#   'child on a red and yellow swing set .',
#   'Two kid play on playground equipment .'],
#  '2573667207_a1bf49befc.jpg': ['A man crouch down on some rock in the ocean .',
#   'A man in a green shirt climb on rock while water rush over them at night .',
#   'A man be stand on some rock while wave lap around him .',
#   'Man crouch on rock by the ocean shore',
#   'A man be lean on rock close to water .'],
#  '2578289278_01516d23a0.jpg': ['a man drag between two horse hold on to a horse on his right',
#   'A man fall off his horse on a racetrack .',
#   'A person be kneel between two horse',
#   'A rodeo contestent be drug between two horse .',
#   'Cowboy in blue and red pants get buck off a horse .'],
#  '2588456052_8842b47005.jpg': ['A female tennis player in a purple top and black skirt swing her racquet .',
#   'A female tennis player prepairing to serve the ball .',
#   'A woman in a purple tank top hold a tennis racket , extend an arm upward , and look up .',
#   'A woman wear a purple shirt and hold a tennis racket in her hand be look up .',
#   'Girl be wait for the ball to come down as she play tennis .'],
#  '2598979962_c01811cfca.jpg': ['a tennis player wear a red shirt about to hit a tennis ball with her racquet .',
#   'A woman in an orange shirt and white skirt hit a tennis ball with a racket .',
#   'A woman in a red shirt , white hat , and white shirt be play tennis .',
#   'A woman swing at a tennis ball .',
#   'Female tennis player on grass prepare a two handed backhand .'],
#  '2616508003_fa5ca5780d.jpg': ['A guy ride a motorcycle on one wheel .',
#   'A man with a red helmet in do a trick on a gray motorcycle .',
#   'A motorcyclist pop a wheelie .',
#   'A person on a motorcycle pop a wheelie in a parkinglot .',
#   'Person do a trick wheelie on a motorcycle .'],
#  '2623496164_68ffeb5067.jpg': ['A biker in red ride in the countryside .',
#   'A biker on a dirt path .',
#   'A person ride a bike off the top of a hill and be airborne .',
#   'A person ride a bmx bike on a dirt course .',
#   'A person on a bicycle be wear red .'],
#  '2652155912_8ba5426790.jpg': ['A gas station and a car on fire .',
#   'A large explosion occur near a red car at a gas station .',
#   'A red car be catch in an explosion .',
#   'a red car be leap through a ball of fire .',
#   'Flame at gas pump engulf a red car .'],
#  '2656890977_7a9f0e4138.jpg': ['A shirtless dark haired boy in gray short be run .',
#   'a skinny young man run with no shirt on',
#   'a small boy in blue short run down a sidewalk with flower in the background',
#   'A small boy , wear short and no shirt , be run outdoors .',
#   'A boy who be walk be wear gray short and no shirt .'],
#  '2656987333_80dcc82c05.jpg': ['A cowboy cover his head as a jump horse trample him .',
#   'A man in a cowboy hat be step on by a brown horse',
#   'A rider have fall off a horse and be shield himself from be trample',
#   'Man with white cowboy hat on the ground behind a brown horse with both front leg off the ground .',
#   'Whoa ! a cowboy be underneath the hoof of a brown horse and be get step on .'],
#  '2657663775_bc98bf67ac.jpg': ['A girl jump over water at a beach .',
#   'a lone person wear a purple tank top run on the shore at a beach',
#   'A woman leap across a beach .',
#   'A woman be wear a purple shirt and run on a beach .',
#   'Woman on beach , run from water to tree .'],
#  '2662537919_18a29fca8a.jpg': ['A closeup shot of a long haired man play a red electric guitar .',
#   'A man rock out onstage with his guitar .',
#   'A man with long blond hair play a red guitar',
#   'Man with long blond hair play red electric guitar .',
#   'Person with blond flyaway hair play guitar'],
#  '2662845514_8620aaee96.jpg': ['A man do a karate kick on a block of ice .',
#   'A man karate kick a stack of ice brick .',
#   'A martial artist break a brick .',
#   'A martial artist break ice with a kick .',
#   'A man break the ice with his foot stand on a blue mat .'],
#  '2685752892_9d5cd7f274.jpg': ['A boy on a bicycle ride the ledge of water fountain while another boy be in a fountain .',
#   'A man on a bike try to do a trick on the railing of an outdoor fountain .',
#   'a man wear a blue shirt and hat jump on one wheel on a fountain ledge',
#   'A young man on a bike balance one wheel on the edge of a fountain in a city park .',
#   'A guy on his bike do a jump near a water fountain .'],
#  '2687529141_edee32649e.jpg': ['Acrobatic entertainer with no shirt perform for spectator .',
#   'a midget jump over another midget .',
#   'Two man in bowler hat and Union Jack underwear perform acrobatics .',
#   'Two man scantily clothe perform acrobatic move in front of a crowd',
#   'Two man wear red and blue trunk and bowler hat be perform in a crowded street .'],
#  '2694178830_116be6a6a9.jpg': ['An athlete perform a high jump .',
#   'A woman athlete launch herself over a bar during a pole vault .',
#   'A woman be black be pole vault .',
#   'A woman pole vaulter upside down as she attempt a vault .',
#   'a woman with her feet in the air about to do pole vault'],
#  '2696636252_91ef1491ea.jpg': ['A man be skate on a rail .',
#   'A person wear Rollerblade slide along a handrail .',
#   'A rollerblader grind a rail and grab one foot .',
#   'A rollerblader grind across a rail .',
#   'Boy in black shirt on one foot stand on metal rail above green grass on right and black pavement on left .'],
#  '2698487246_e827404cac.jpg': ['A man in a black and white jersey be leap to get a ball from a player in a blue and yellow jersey .',
#   'People play a sport with a referee look on .',
#   'Men be jump in the air .',
#   'Three rugby player try to catch the ball',
#   'Two man be jump into the air to catch the football .'],
#  '2698614194_b4e6e11dff.jpg': ['five man play football .',
#   'Five young man play rugby .',
#   'A player wear black and white jersey jump for the ball amidst two player from the other team as his two teammate run to help him .',
#   'Three man leap in the air in an effort to grab the ball .',
#   'Three rugby player all try to catch a ball .'],
#  '269986132_91b71e8aaa.jpg': ['A group of soccer player after a ball .',
#   'A soccer game between the red team and the blue team .',
#   'A soccer game be in progress .',
#   'Soccer game with team in red and blue .',
#   'two team of soccer player play a game on a field'],
#  '2700147489_f1664f2b61.jpg': ['A guy skateboard on a basketball court',
#   'A man jump in the air while perform a stunt on his skateboard .',
#   'a skateboarder ollies .',
#   'Man with beard do skateboard stunt',
#   'A guy in gray pants be complete a jump on his skateboard .'],
#  '2708176152_1634cb754d.jpg': ['A group of bicyclist in a race .',
#   'A group of person in a bicycle race .',
#   'A group of person ride bicycle around a curve on a racetrack .',
#   'Group of cyclist in ride gear with helmet .',
#   'Men race on bicycle on track .'],
#  '2710563762_06d48329d7.jpg': ['A girl basketball player wear blue be block another girl player wear yellow .',
#   'A group of person gather on a basketball court as one person jump for the ball .',
#   'Basketball player jump up for the ball during a game .',
#   'Girl be play basketball .',
#   'two team of player play basketball on a court outside .'],
#  '2712352554_1cafd32812.jpg': ['A boy do a skateboard trick off a metal plank .',
#   'a guy with no shirt on is skateboard .',
#   'A young man jump in the air on a skateboard .',
#   'Skateboarder on a rail .',
#   'Skater do a trick on a rail .'],
#  '2718376488_3c62f7642c.jpg': ['A group of bull be run down a street as person run and others watch .',
#   'Cows and person run down street',
#   'Hundred of person watch as person partake in a bull-run .',
#   'Bull be chase runner .',
#   'Bull be come down a street with person to the right of them and a building behind them .'],
#  '2719101587_4ba70dee14.jpg': ['A guy do trick on a motorcycle .',
#   'a motorcyclist do a nose wheelie .',
#   'A person in a specialized suit ride a motorcycle .',
#   'Motorcyclist perform while two man watch .',
#   'A rider be drive their motorcycle .'],
#  '2719102611_fef453bf30.jpg': ['A man in a black and white uniform stand on a motorbike do a stunt .',
#   'A motorcycle rider stand on top of his bike .',
#   'A motorcycle rider start to sand up on the seat of his white motorcycle .',
#   'Someone be on a black and white motorcycle and put their feet on a seat .',
#   'This person be do a stunt on a motorcycle .'],
#  '273248777_eaf0288ab3.jpg': ['A football player in a full stadium jump and recieving a football .',
#   'An American footballer in yellow catch the ball whilst under pressure from a payer in white .',
#   'Two football player play football before a huge crowd .',
#   'Two football player run into each other .',
#   'Two man vie for a football .'],
#  '2735158990_56ff6bf9b0.jpg': ['A brown and white dog stand on his hind leg and bark .',
#   'A brown dog on his hind leg in the shadow of some tree .',
#   'A dog jump in the wood .',
#   'A dog stand on its hind leg in a wooded area while another dog watch .',
#   'A white dog be jump in the air to catch a ball in the wood .'],
#  '2736508369_fd9ff0b42f.jpg': ['A baseball player be tag out slide into second base .',
#   'A baseball player slide toward a base .',
#   'a man in a gray uniform slide into a base',
#   'Three man play baseball .',
#   'two fielder be defend the base as a member of a bat team slide towards it .'],
#  '2737233999_34d60dc5c3.jpg': ['Four child play basketball .',
#   'Four person be play basketball on a plank deck outdoors .',
#   'Four person play basketball on wooden area near a beach .',
#   'Kid play basketball on a wood deck .',
#   'Young child shoot basket in the field .'],
#  '2737609659_efce872c24.jpg': ['A four wheel drive vehicle be drive on a dirt track .',
#   'A girl wear camouflage pants sit on top of a Hummer .',
#   'Girl on roof of jeep be drive down road',
#   'In rural outdoors , blond woman sit on roof of yellow Bmw vehicle , two person inside .',
#   'Two person drive a Jeep while a lady sit on the top of it .'],
#  '2744600462_5804577296.jpg': ['A cyclist don blue and white be lead a pack of cyclist .',
#   'A large column of bicyclist be cycle down a road .',
#   'A pack of bicycle road racer lean through a curve .',
#   'A pack of bicyclist take a turn during a race .',
#   'Cyclist compete in a race be come around a bend in a road .'],
#  '2745663684_650f84e1e6.jpg': ['A boy in a tank top skateboard .',
#   'A boy skateboard down a street .',
#   'A kid in a striped tank top skateboard down a street',
#   'A man wear short and a tank top ride a skateboard .',
#   'a young man skateboard on a street wear a black and white striped shirt'],
#  '2747436384_9470c56cb9.jpg': ['Boy with their back against an incoming wave .',
#   'Four boy be about to be hit by an approach wave .',
#   'Four person sit in the path of a wave .',
#   'Four young man be sit on a beach under a crash wave .',
#   'three boy sit in sand get splash by wave'],
#  '2748729903_3c7c920c4d.jpg': ['a man crash into the water with his parachute .',
#   'A parasailer splash along the surface of a lake .',
#   'A person hang from a parachute make a splash as their body hit the water .',
#   'A person in a parachute slide across the water .',
#   'A parasailer be skip across the water .'],
#  '2755952680_68a0a1fa42.jpg': ['a bicyclist jump with his bike in midair',
#   'A cyclist be perform a jump whilst other cyclist stand by and watch .',
#   'A guy be do a trick on a bike .',
#   'Someone on a bike be perform an aerial trick while other biker watch .',
#   'A trick bicyclist get airborne off a ramp .'],
#  '2764178773_d63b502812.jpg': ['A bike rider be do a stunt on a bicycle over a forest .',
#   'A man do a bicycle trick .',
#   'A man be attempt a stunt with a bicycle .',
#   'a man be perform an aerial jump on a bicycle in front of a mountain cover with pine tree .',
#   'A person be hold onto a bicycle in the air with his body in flight position .'],
#  '2765029348_667111fc30.jpg': ['A biker flip upside down .',
#   'A man do a flip trick on his bicycle .',
#   'A man be do a back flip off a ramp on a mountain bike in the wild .',
#   'A man be do a back flip whilst attempt a jump on a bicycle .',
#   'A man perform a back flip on his bmx bicycle .'],
#  '2766765386_4c0beb939d.jpg': ['A lone surfer ride a huge wave in the ocean .',
#   'A man in a black wetsuit be surfung in the wave .',
#   'A surfer in a black wetsuit be ride a foamy wave .',
#   'A surfer in a black wetsuit surf on a medium wave .',
#   'a surfer surf a huge wave .'],
#  '2768248810_06d543c080.jpg': ['A man , feet fasten to a board and hold a tow-rope become airborne over the water .',
#   'A man water board .',
#   'A man waterskis .',
#   'A wakeboarder be do a jump trick in the water .',
#   'A wakeboarder be leap into an air whilst hold onto a pink rope .'],
#  '2788628994_61123c03d2.jpg': ['A man in a blue jacket bike down a forest path .',
#   'A man ride a bike down a trail in a pine forest .',
#   'A person on a bike ride through a wooded area .',
#   'Tall tree reach to the horizon as a cyclist navigate the way through tangled root .',
#   'A biker be ride through the wood .'],
#  '2792195540_af5fb95caa.jpg': ['Above view of multiple person skydive .',
#   'A group of person be show sky-diving as they fall through the sky .',
#   'A sky jumper fall toward the sea and the earth .',
#   'People be skydive .',
#   'Skydiver in formation .'],
#  '2795866891_7559fd8422.jpg': ['A boy in short do a skateboard trick .',
#   'A man do skateboard trick in a park lot at night .',
#   'a skateboarder grind a curb .',
#   'a skateboarder be ride his board along the boundary stone of a park lot .',
#   'A skateboard be grind on a curb with his skateboard .'],
#  '2796801478_8ebd7e550b.jpg': ['A man ride his skateboard with his shadow fall on a wall cover in graffiti .',
#   'A skateboarder grind a lip .',
#   'A skateboarder be jump through the air in front of a graffiti covered wall .',
#   'A skateboarder perform a skateboard trick against a graffiti wall .',
#   'A skateboarder perform trick on a ramp in front of a wall with graffiti .'],
#  '2812590023_50182bc417.jpg': ['A Budweiser-sponsored race car accelerates quick with smoke behind it .',
#   'A dragster be take off and leave a huge trail of smoke behind him .',
#   'A man be photograph a Budweiser sprint car at a speedway smoke its tire .',
#   'Red race car on track blow smoke',
#   'Smoke be spew out of the back of a red race car on a racetrack .'],
#  '2813784259_d201044d71.jpg': ['A boy wear a white headband be kick a soccer ball down the field .',
#   'A player kick the soccer ball from the corner of the field .',
#   'A soccer game be go on at sundown .',
#   'A soccer player be kick a soccer ball .',
#   'At dusk , a soccer player kick the ball off the sideline .'],
#  '2813992915_f732cf8539.jpg': ['A man be do trick on a bicycle on ramp in front of a crowd .',
#   'A man on a bike execute a jump as part of a competition while a crowd watch .',
#   'A man ride a yellow bike over a ramp while others watch .',
#   'Bike rider jump obstacle .',
#   'Bmx biker Jump off of ramp'],
#  '2817230861_d27341dec0.jpg': ['Two female beach volleyball player face off at a net with the Beijing Olympics logo visible in the background .',
#   'two female volleyball player try to hit the ball .',
#   'Two woman play beach volleyball .',
#   'Two woman in skimpy outfit play sand volleyball .',
#   'Two woman play volleyball on the sand .'],
#  '2825483885_3f7c54db3e.jpg': ['A man in a dress suit be ride a bike down a paved road .',
#   'A man on a bike be ride along the side of a country road',
#   'An old gentleman ride his bike along the side of a road in a rural area .',
#   'An old man ride a bicycle on a country road .',
#   'Man ride a bicycle down a road with cloud overhead .'],
#  '2825668136_107223182c.jpg': ['A bike rider jump off his bike , do a trick',
#   'A guy be do a trick on a bike .',
#   'A man be perform a jump trip on his bicycle .',
#   'A man with a bike jump high above the concrete .',
#   'Bike rider jump off of gray stone rise , do trick in air .'],
#  '2831578193_3c997ae330.jpg': ['A person feed a strawberry to a turtle',
#   'A tortoise attempt to eat a berry .',
#   'Someone feed a strawberry to a turtle .',
#   'A tortoise be be feed an strawberry .',
#   'A turtle be be feed a strawberry'],
#  '2837799692_2f1c50722a.jpg': ['A football player have the number 25 .',
#   'A football player , his helmet half off , look at the ground .',
#   'A football player wear a white uniform walk and look down .',
#   'a university of Miami football player # 25 .',
#   'Closeup of football player # 25 .'],
#  '2838085973_42b6e9b5b1.jpg': ['A football player prepare to throw the ball .',
#   'A guy with a football , a crowd watch him .',
#   'A man wear a white uniform be play football .',
#   'quarterback for University of Florida',
#   'A football player be prepare to make a play with onlooker nearby .'],
#  '2840344516_8e15fe2668.jpg': ['A boat go out to see while someone watch on a beach .',
#   'An orange boat leave the shore while a person watch nearby .',
#   'An orange lifeboat speed away from its mobile launcher whilst a man in red watch it sail away .',
#   'A vehicle have just release a boat into the water as a man in red stand on shore .',
#   'A boat rush off .'],
#  '2842439618_fb20fe2215.jpg': ['A person be stand on a surfboard and ride down a large wave .',
#   'A person be surf on a wave while another person head towards it .',
#   'A surfer in a black wetsuit catch a wave while another one try to catch up with him .',
#   'One surfer ride a wave while another surfer paddle at the base of a wave .',
#   'Someone be surf along a wave with someone else swim nearby .'],
#  '2844963839_ff09cdb81f.jpg': ['a group of football player huddle together in the middle of the field .',
#   'A group of football player wear orange and blue uniform gather together on the field .',
#   'Football player in blue and orange uniform be huddle together and hug each other .',
#   'Football player in uniform embrace one another .',
#   'Men in the Gator helmet have their arm wrap around each other .'],
#  '2845845721_d0bc113ff7.jpg': ['A man in jean be play with a ball while a woman in jean stand nearby look away .',
#   'A man run across the grass towards a woman .',
#   'A woman stand in a field with her hand on her hip while a man run up behind her .',
#   'A woman wear black be stand in a grassy field as a man in a blue cap run .',
#   'Two person in a field look off-camera .'],
#  '2846785268_904c5fcf9f.jpg': ['A boy do a trick on top of a guardrail on inline skate .',
#   'A person jump onto a barrier .',
#   'A person wear Rollerblade jump over a yellow gate .',
#   'A young adult jump on a yellow barricade .',
#   'Rollerblader grind a yellow road barrier'],
#  '2848977044_446a31d86e.jpg': ['A cowboy be hang upside down from a horse .',
#   'A man at a rodeo be ride his horse while upside down and not on a saddle',
#   'A man be ride upside down on the side of a horse at a rodeo .',
#   'A rodeo rider be throw headfirst from a horse .',
#   'A rodeo rider do a vertical trick on a brown horse as an audience look on .'],
#  '2850719435_221f15e951.jpg': ['A boy in a red shirt and a boy in a yellow shirt be jump on a trampoline outside .',
#   'child jump on a trampoline .',
#   'Kid be jump on a blue rimmed trampoline .',
#   'Two child be play on a teal trampoline near greenery .',
#   'Two young boy jump on a trampoline as two other child sit on it .'],
#  '2851198725_37b6027625.jpg': ['A man be kayak in rough water .',
#   'A man be kayak through some white water .',
#   'Man kayak in a rage river .',
#   'Man kayak down river rapid .',
#   'A man in a yellow jacket be paddle a red kayak through white water .'],
#  '2855594918_1d1e6a6061.jpg': ['A biker , all cover in mud , ride a blue bike .',
#   'Biker in muddy orange shirt ride blue race bike',
#   'One man in an orange shirt wear a white helmet be ride a bike .',
#   'Person with orange shirt and black and white helmet ride bike',
#   'A man on a bike just finish ride through some mud .'],
#  '2855910826_d075845288.jpg': ['A football player in a blue and yellow uniform be tackle another player in a white and gold uniform .',
#   'Player on a football team scuffle in an attempt to get the ball .',
#   'Two football player be tackle an oppose football player with a referee nearby .',
#   'Two football player be tackle a third while a referee watch .',
#   'two football player tackle another football player .'],
#  '2856456013_335297f587.jpg': ['A soccer player in a white shirt move to run past a player from the opposite team .',
#   'Guy in white try to score in soccer while be block by two guy in orange and black',
#   'Number 3 have the soccer ball go around number 6 in a red jersey .',
#   'A soccer player in red be try to block a player in white .',
#   'Three boy play soccer .'],
#  '2856524322_1d04452a21.jpg': ['A man on a bicycle jump off a dirt ramp with one foot on the ground',
#   'A man on a bmx .',
#   'A man ride a bicycle perform a trick above a dirt mound .',
#   'A young man in tan short and green shirt be fall off his bicycle .',
#   'Man do a jump bike trick on dirt mound at night .'],
#  '2856923934_6eb8832c9a.jpg': ['A man steer a speed jet ski through a turn .',
#   'Two man be in a blue and white speed boat .',
#   'Two man be ride a blue and white jet ski .',
#   'Two person be drive a blue jet ski , leave a trail of water in the air .',
#   'Two person jetski on a blue jet ski .'],
#  '2858439751_daa3a30ab8.jpg': ['A green motorcycle be be ride on a wet racetrack .',
#   'a man on a race bike',
#   'A man ride a green motorcycle on a wet racetrack .',
#   'A motorcycle racer be turn around a curve on a wet road .',
#   'Person ride a green race motorcycle .'],
#  '2860372882_e0ef4131d4.jpg': ['A man in bright orange short be skateboard along a course with cone as two person observe in the background .',
#   'A man in orange short and knee pad be in a blurry picture .',
#   'A man in orange short , knee pad and a helmet , move quick on a street course .',
#   'a man in orange short move really fast',
#   'A skater go through a course .'],
#  '2860400846_2c1026a573.jpg': ['a tan and white dog jump after a red Frisbee .',
#   'A white dog be run towards a red Frisbee on the grass .',
#   'A white dog jump above a red Frisbee that be roll along the surface of a low cut field .',
#   'A white dog wear a red collar jump up after a red Frisbee .',
#   'Dog jump in the air run after the Frisbee .'],
#  '2860667542_95abec3380.jpg': ['A big white bird fly out of the water leave a splash .',
#   'a crane fly just above a body of water',
#   'A white water bird take flight from a lake .',
#   'Long-necked , fly white bird graze water with black leg .',
#   'A white crane be land in the water .'],
#  '2861413434_f0e2a10179.jpg': ['A boy wear a blue jacket swing a bat at a white ball .',
#   'A little boy in a blue coat hit a ball with a stick .',
#   'A little boy in a blue jacket hit a baseball .',
#   'A young boy in a blue jacket swing a bat at a ball .',
#   'A boy in a blue jacket and gray cap be play with a ball .'],
#  '2862509442_4f5dc96dca.jpg': ['A crowd watch as two formula one car leave the start line .',
#   'A crowd watch the start of a drag race at twilight .',
#   'A group of person watch a drag race at the begin and see a fire from car .',
#   'People look at flame come from car at a drag race .',
#   'Drag racer take off the start line .'],
#  '2862931640_2501bd36c5.jpg': ['A group of young person pose for a group photo while a man do a bike jump .',
#   'A person jump off a ramp on a bike over a crowd .',
#   'A topless guy jump a ramp on a bike .',
#   'People cheer as a bicyclist ride his bike off a ramp',
#   'People cheer as a man ride a bmx bike in midair'],
#  '2863027424_9c75105660.jpg': ['A bicyclist with a green shirt ride through the wood',
#   'A man in green bike in the wood .',
#   'A man be ride a mountain bike on a woodland trail .',
#   'A man ride a bike through a wooded trail .',
#   'A mountain biker be ride along a heavy dirt trail in a wooded area .'],
#  '2863180332_372510aa49.jpg': ['A person on a downhill skateboard .',
#   'A person wear a helmet and red and silver jumpsuit be kneel on a skateboard .',
#   'A person wear a helmet begin to ride a skateboard down a street hill .',
#   'People in helmet race down a street on skateboard .',
#   'People ride skateboard on a road .'],
#  '2864634088_d087494dff.jpg': ['A group of person ride bicycle turn on a street .',
#   'a large group of bicycle race on a street',
#   'A line of man on bicycle compete in a race',
#   'A tight crowd of bicycler make a sharp turn in a race .',
#   'Lots of cyclist ride during a race .'],
#  '2865564810_5c63328cd4.jpg': ['A biker do a somersault with a bike in front of a crowd .',
#   'Biker perform jump while onlooker watch .',
#   'Someone do a flip trick on a red bicycle in front of a lot of person .',
#   'An athlete perfomed a trick as a large crown watch .',
#   'A rider on a red Bmx bike do an inverted trick .'],
#  '2865703567_52de2444f2.jpg': ['A man be jump across a gap .',
#   'a man jump from one building to another closeby',
#   'A man jump off a large building onto the ground .',
#   'A man jump off of one rooftop onto another .',
#   'A young man jump from one balcony to another .'],
#  '2866093652_aa717eb9ce.jpg': ['Four person rollerskate with spectator in the background .',
#   'Four woman competitively rollerskate around an area .',
#   'four woman rollerblade .',
#   'Three woman participate in a roller derby .',
#   'Woman skater on a skate rink in athletic equipment .'],
#  '2866254827_9a8f592017.jpg': ['A man on a motorcycle ride on his back tire .',
#   'A man on a yellow sport bike do a wheelie as his friend on a black bike catch up .',
#   'A yellow motorcyclist be pop a wheelie .',
#   'An orange rider be drive a motorcycle on one wheel .',
#   'Two motorcyclist on a blurry road , one rider do a wheelie .'],
#  '2866696346_4dcccbd3a5.jpg': ['A skateboarder wear an orange shirt and orange helmet .',
#   'Men ride skateboard .',
#   'Two man , both wear helmet , on skateboard with large wheel .',
#   'Two man on skateboard , and one have an orange helmet .',
#   'Two man skateboard at high speed .'],
#  '2867968184_908d87cf2c.jpg': ['A man do a skateboard trick in air while be videotape .',
#   'A man perform a skateboard trick .',
#   'A teenager boy do a trick with his skateboard against a wall .',
#   'A boy be skateboard .',
#   'Skateboarder wear jean and a white shirt jump a ramp .'],
#  '2869009633_ea3cafd437.jpg': ['four girl play volleyball .',
#   'Four woman be play on a beach as a huge ship pass in the background .',
#   'Four woman in bathe suit be play on a beach .',
#   'Slightly overweight woman in bikini be play on a beach .',
#   'Woman play volleyball in the sand near the ocean .'],
#  '2871962580_b85ce502ba.jpg': ['A football player in mid stride hold a football .',
#   'A football player be run with a football .',
#   'A football player with a football be be pursue by another player .',
#   'An american footballer in a white strip who be carry the ball be be pursue by another player in a black strip .',
#   'One football player hold the ball be chase by another football player from the oppose team'],
#  '2872963574_52ab5182cb.jpg': ['A hockey player in black and white collides with another player wear blue .',
#   'Hockey player collide on the ice .',
#   'An ice hockey player in white be tumble in front of a player in blue .',
#   'Two hockey player bump against each other while skate on the ice .',
#   'Two oppose hockey player collide .'],
#  '2873065944_29c01782e2.jpg': ['A football player be tackle during a game .',
#   'A football player have his arm wrap around a person hold the ball .',
#   'A football player in orange be tackle by a player in blue .',
#   'A young boy wear orange be run with the football as a boy in blue try to wrestle him to the ground .',
#   'Boy in orange jersey have the football and be be tackle .'],
#  '2873070704_2141a7a86a.jpg': ['A man in a blue shirt be rock climb .',
#   'A man in blue be climb up a rocky cliff with the help of secured cord .',
#   'An overhead view of a guy rock climb .',
#   'A person in blue climb up a very tall cliff , attach by red and blue rope .',
#   'A rock climber make his way up a mountain .'],
#  '2873188959_ff023defa9.jpg': ['a man in blue short leap from cliff into a lake .',
#   'A man in swim trunk jump off a rock into a lake .',
#   'A man jump from a rock into the water .',
#   'a shirtless man jump into the water .',
#   'A young man take an acrobatic leap into the water .'],
#  '2873252292_ebf23f5f10.jpg': ['A man on a bicycle ride on a mountain .',
#   'A mountain biker make his way up a grassy path on his red bicycle .',
#   'A mountain biker ride up a hill on a red bicycle .',
#   'A mountain biker with a backpack crest a ridge .',
#   'Someone in a yellow jacket mountain bike on a red bike .'],
#  '2873522522_829ea62491.jpg': ['A group of man play soccer .',
# ...
#  '3420278866_1d17c12713.jpg': ['Andy Rodderick get ready to hit a tennis ball .',
#   'Andy Roddick play tennis .',
#   'A tennis player in mid game hold a racquet .',
#   'Man dress in black and white hold his tennis racket up wait for the ball .',
#   'Tennis player get ready to play tennis .'],
#  '3420284416_a90af1fb7a.jpg': ['A baseball player be on the field in fronmt of an audience .',
#   'A man in a black top and white cap be stretch backwards in a sport stadium .',
#   'A man wear a white hat swing his arm back to throw .',
#   'A tennis player about to serve .',
#   'Tennis player be serve the ball .'],
#  '3421177332_a05741cfa4.jpg': ['A man in black be applaud a runner wear a red jersey and the number 281 .',
#   'A runner during a race .',
#   'Runner number 281 be be clap on by a passerby .',
#   'A man be run a race be be cheer on by spectator .',
#   'The runner be wear a red tank top and be be watch by a man in black .'],
#  '3421547427_53411b6278.jpg': ['A man in a blue shirt lift up his tennis racket and smile .',
#   'A man play tennis look very happy .',
#   'A tennis player in a blue shirt celebrate his match .',
#   'A tennis player wear a blue shirt raise his hand and smile .',
#   'A tennis player in a blue shirt be hold his racquet up in the air .'],
#  '3421706363_a3e22a4908.jpg': ['A boy in dark pants and green t-shirt ride his bike up a ramp .',
#   'A man be jump his bicycle off a ramp in a skate park .',
#   'A man wear a yellow shirt jump his bike over a ramp .',
#   'A teen boy do a bicycle trick on a bike ramp',
#   'A young man be perform a bicycle jump on a ramp .'],
#  '3421928157_69a325366f.jpg': ['A group of man in an unner tube go over some rapid',
#   'A raft with a group of person be turn over after a crash wave .',
#   'People be toss around in a blue raft in a foamy river .',
#   'Two blue inflatable raft be involve in a collision on white water .',
#   'Two raft overturn in a river .'],
#  '3422219732_3d0be52cc3.jpg': ['An individual be ski down a mountain slope .',
#   'A person ski down a snowy mountainside .',
#   'A skier be ski down a very steep slope with a mountain in the background .',
#   'A skier go down a near vertical slope .',
#   'Skier come down a very steep snow peak .'],
#  '3422458549_f3f3878dbf.jpg': ['An african american woman dress in orange be hit a tennis ball with a racquet .',
#   'A tennis player in an orange outfit hit a ball .',
#   'A tennis player in orange be strike the ball with her racquet .',
#   'A woman in an orange athletic outfit play tennis',
#   'Serena Williams hit a ball in an orange outfit'],
#  '3423225860_16e26eef74.jpg': ['A female tennis player wear orange in the middle of a tennis match .',
#   'An african american woman be lean over while hold a tennis racket .',
#   'a tennis player wear an orange tennis outfit on the court .',
#   'A woman play tennis , swing her racket .',
#   'Woman play tennis in a bright orange outfit .'],
#  '3423509305_e399d005db.jpg': ['A brown dog wear an orange collar leap to catch a bright colored ball .',
#   'A dog catch a ball',
#   'A dog leap away with a ball in its mouth .',
#   'A dog leap high to catch a ball .',
#   'A jog be jump in the air to catch a ball in a backyard .'],
#  '3424424006_98f9d1921c.jpg': ['A bride and groom jump towards each other with arm outstretched .',
#   "A groom leap off of a stone wall and into his wife 's arm .",
#   'A man in a suit leap toward his bride .',
#   'A man in a tuxedo jump toward a woman in a wed dress .',
#   'A man in wetsuit jump towards a wet bride .'],
#  '3425061393_d093edb8da.jpg': ['a man get ready to hit the tennis ball .',
#   'A tennis player move for a shot .',
#   'A tennis player with green a green headband on is ready to hit the ball .',
#   'Tennis champ Rafael Nadal lunge to return a ball .',
#   'Tennis player lunge to the left .'],
#  '3425069551_aba046a1b6.jpg': ['A male tennis player pump his fist .',
#   'a male tennis player with a blue headband be hold a racquet',
#   'a man in a pink and yellow shirt and blue headband be hold a tennis racquet whilst stand with his mouth open .',
#   'A man with a tennis racket be wear a blue headband and blue wristband and play tennis .',
#   'Nadal celebrate , wear a green headband'],
#  '3425071001_e7c9809ef2.jpg': ['A boy hit a tennis ball on a court .',
#   'A boy hit a tennis ball with a black and yellow racket .',
#   'A boy hit a tennis ball with his tennis racquet .',
#   'A boy play tennis .',
#   'A teenage boy hit a tennis ball with a racket .'],
#  '3425127583_611200619a.jpg': ['A male tennis player run for a shot .',
#   'A man have a racquet in his hand and be play a game of tennis .',
#   'A man with a tennis racket go for the ball .',
#   'a tennis player be run on the court with his racquet in his hand .',
#   'a tennis player run for the ball .'],
#  '3425662680_41c7c50e8d.jpg': ['A group of horse and rider be play polo on the grass .',
#   'A group of horse and their rider be race each other .',
#   'A horse race on a grass track',
#   'Jockey be ride their horse down a track .',
#   'Jockey race horse down a grass track .'],
#  '3425756814_13909354d4.jpg': ['A male tennis player hold his tennis racket .',
#   'A man hold a tennis racket be look in the distance with his hand over his mouth .',
#   'A man in a sleeveless blue tennis shirt blow kiss to fan .',
#   'A tennis player hold one hand to his mouth and the other hold a racket .',
#   'a tennis player in a green striped shirt be hold his hand up to his mouth .'],
#  '3425846980_912943b4f9.jpg': ['A guy play tennis , two nearby spectator , and a crowd watch .',
#   'A tennis player hit a ball .',
#   'A tennis player get ready to hit the ball that be almost at him .',
#   'A tennis player be hit the ball with his racquet , while others watch a match .',
#   'A tennis player wear white hit the tennis ball .'],
#  '3425851292_de92a072ee.jpg': ['A male athlete be wear a teal sweatband and a shirt from Nike and be hold a tennis racket .',
#   'A man play tennis .',
#   'A tennis player be carry a tennis racket .',
#   'a tennis player wear a yellow , white and blue shirt carry a racquet',
#   'A tennis player be wear a yellow and blue shirt and a blue headband .'],
#  '3425853460_bfcd0b41f6.jpg': ['A man hit a tennis ball during a professional match .',
#   'A man hit the tennis ball with his racket .',
#   'A man in a blue headband play tennis .',
#   'A man be hit a tennis ball in a professional match .',
#   'A man with a green headband play tennis .'],
#  '3425887426_bf60b8afa3.jpg': ['A person hold a tennis racket hit a yellow tennis ball .',
#   'A tennis player hit the ball',
#   'A tennis player hit the ball .',
#   'The tennis ball be about to be hit .',
#   'This man be hit a tennis ball with a tennis racket .'],
#  '3427614912_b147d083b2.jpg': ['Two boy be sprint on a run track .',
#   'Two boy race each other on foot .',
#   'Two man in a run contest .',
#   'two young man run along a track .',
#   'Two young man run on a track outside .'],
#  '3427852996_d383abd819.jpg': ['A biker pop a wheelie along side the colorful wall .',
#   'A bmx rider do a trick against a graffiti covered wall .',
#   'A boy perform a wall trick with his bicycle on a wall cover with graffiti .',
#   'A man on a small bicycle perform a trick on a wall cover with graffiti .',
#   'A trial biker do a stunt on a graffiti-filled wall .'],
#  '3428386573_670f5362f0.jpg': ['A male tennis player stand on a tennis court swing his tennis racket at the tennis ball .',
#   'A man play tennis .',
#   'A man wear white turn to hit a yellow tennis ball .',
#   'A tennis player focus on the ball as he prepare to hit it , while a cameraman stand in the background next to a La Quinta advertise logo .',
#   'A tennis player hold his racket up anticipate the ball .'],
#  '3429194423_98e911a101.jpg': ['A man do a trick on ski .',
#   'A man make an X with his ski as he jump .',
#   'A skier in a plaid jacket fly through the air against a dark blue sky .',
#   "Person in dark pants and print top on ski 's in the air over snow cover ground .",
#   'A person be jump through the air on ski .'],
#  '3429391520_930b153f94.jpg': ['A bicyclist catch some air',
#   'A helmeted boy on a bike fly through the air as he ride among dirt hill with a river in the background .',
#   'A man be do a stunt outside on his bike',
#   'Bike rider do a high jump over hill track , water in background .',
#   'This helmeted person be do a stunt on a bicycle outdoors .'],
#  '3430287726_94a1825bbf.jpg': ['a man in a black outfit be ride a blue snowmobile across the snow .',
#   'A man ride a purple snowmobile',
#   'A man wear snow clothes and a helmet drive a snow vehicle in the snow .',
#   'A man with a helmet be go snowmobile .',
#   'A person ride a snowmobile on large amount of snow .'],
#  '3430607596_7e4f74e3ff.jpg': ['A boy in a red suit play in the water .',
#   'A boy in a red swimsuit jump into the water to join two person .',
#   'A boy take a fly leap into the water .',
#   'A boy in red short jump into the water to join other person .',
#   'A boy wear red short be jump into a river as other child swim .'],
#  '3430779304_43a2146f4b.jpg': ['Two cowboy on horseback lasso a young calf to the ground .',
#   'Two cowboy on horse wrangle a calf in a rodeo .',
#   'Two cowboy rope a steer from horseback in an indoor corral .',
#   'Two man ride horse and a calf run between them .',
#   'Two person on horse chase cow in an arena .'],
#  '3430782104_34da558eba.jpg': ['A cowboy on a horse rope a steer .',
#   'A cowboy try to rope a bull while on a horse',
#   'A cowboy wrangle a calf in a rodeo .',
#   'a girl on a horse try to catch a bull with a rope',
#   'A person attempt to rope a black cow while ride a horse .'],
#  '3431121650_056db85987.jpg': ['Dog run out of the water toward a rocky beach .',
#   'Three dog be in the water next to a rocky shorline .',
#   'Three dog play in the shallow next to a rocky shore .',
#   'Two large dog and a small dog play in a lake .',
#   'Two medium dog and a small dog be play in shallow water .'],
#  '3431261634_c73360406a.jpg': ['A man in a blue wetsuit surf .',
#   'A surfer in blue ride a wave .',
#   'A surfer be be splash by an ocean wave .',
#   'a surfer make a big splash .',
#   'Person with a blue and black suit be surf .'],
#  '3431671749_e8e3a449ac.jpg': ['A car be zoom off with fire come out of its exhaust pipe .',
#   'A race car have fire shoot out the back .',
#   'A race car on a track have flame shoot from the rear .',
#   'Fire be come out of the back of a race car .',
#   'Flame be shoot from the rear of a race car .'],
#  '3432550415_e7b77232de.jpg': ['A boy stand on railing',
#   'A boy stand on a rail with his arm outstretched .',
#   'An inline skater be attempt a trick in a long metal rail behind a large structure .',
#   'A skateboarder be ride a skateboard along a metal railing in front of a concrete building .',
#   'A boy be do a trick on a rail next to an overpass .'],
#  '3434526008_02359881a0.jpg': ['A man in a sleeveless shirt be perform an aerial stunt along a graffiti-covered wall .',
#   'a man jump of the wall of a large graffitied wall .',
#   'A skateboarder use a ramp .',
#   'A young man skate down the side of a colorful wall .',
#   'A man be wear a no sleeve shirt and blue jean on a graffiti wall .'],
#  '3435015880_eda46ff50f.jpg': ['a guy and a girl jump up in the air',
#   'A man and a woman be run and jump on top of a hill .',
#   'Two person be run at the top of a mountain .',
#   'Two person jump up and down on a cliff overlook a valley .',
#   'Two woman jump in the grass atop a mountain .'],
#  '3435233065_3411f2d29d.jpg': ['A biker do a jump in a forest .',
#   'a boy do a jump on his bike in the wood',
#   'A boy on a mountain bike land after a jump while ride in a forest .',
#   'A guy race his motorcycle on a trail .',
#   'A man be ride his bicycle through the wood .'],
#  '3435653630_3b6cca2c40.jpg': ['A basketball team of 8 girl be do a hand huddle .',
#   'A group of basketball player in a huddle .',
#   'A sport team be in a huddle with hand together .',
#   'Basketball player huddle .',
#   'Player wear black'],
#  '3437147889_4cf26dd525.jpg': ['Two bmx rider race on a track',
#   'Two motocross bike be be race around a dirt track .',
#   'Two motocross rider next to each other on a dirt track .',
#   'Two motorcyclist be on a dirt track .',
#   'Two person wear race uniform be ride race motorcycle .'],
#  '3437654963_c4fdc17e8b.jpg': ['A mama bear and its cub be growl directly at one another .',
#   'Bear be face each other with their mouth wide open .',
#   'Two bear be growl at each other .',
#   'Two bear bare their teeth at one another .',
#   'Two brown bear touch , face to face , with mouth open .'],
#  '3437781040_82b06facb3.jpg': ['An ice hockey player in red be challenge a player in white for the puck .',
#   'The goalie have come out of the goal to steal the puck from the other team .',
#   'Two athlete play in a hockey game .',
#   'Two hockey player try to get the puck .',
#   'Two hockey player try to get control of the puck as the referee look on .'],
#  '3438858409_136345fa07.jpg': ['A group of man in camouflage pants , break dance on a stage at a community baseball field .',
#   'a man give another man a piggy back ride .',
#   'Four man dance on a stage wear yellow and orange shirt .',
#   'Three man climb on each other wear yellow and brown shirt .',
#   'Two man in yellow be dance with two man in brown on a stage .'],
#  '3438981089_2ef1a6353c.jpg': ['a bmx rider get some air .',
#   'A man in a black t-shirt be jump something on his orange bike .',
#   'A man on an orange bike .',
#   'A man on an orange bike jump in the air with the city line behind him .',
#   'A man be perform a trick with an orange bicycle .'],
#  '3439331800_e71e1d808f.jpg': ['A group of dancer onstage .',
#   'Four man do a dance onstage together .',
#   'Four man do a synchronized dance on an outdoor stage .',
#   'four young man perform on a stage .',
#   'Four young man dance onstage .'],
#  '3439382048_d2e23b2b4c.jpg': ['A bald man be attempt to slam dunk a basketball in a game while person in the stand watch .',
#   'A basketball player be jump and about to dunk a ball in front of a crowd .',
#   'A man reach toward dunk a basketball while an audience watch .',
#   'A tattooed man dunks a basketball .',
#   'A tattooed basketball player be about to dunk the ball .'],
#  '3440952969_608eb5e42b.jpg': ['A long haired skateboarder be airborne above a set of cement step and a metal Bannister .',
#   'A man jump a rail on his skateboard .',
#   'A person ride a skateboard jump high above the concrete step .',
#   'A skateboarder prop up on a pole just before descend .',
#   'A skateboarder try to do a trick down the railing .'],
#  '3441145615_b4fcd9eea0.jpg': ['A group of cycler race around a track .',
#   'A group of person in colored outfit ride bike around a track .',
#   'Bicyclist stay in a line as each wear different color suit .',
#   'Multiple bicyclist wear different colored shirt and helmet ride around a track .',
#   'Ten cyclist in different color be race around a bend in a track .'],
#  '3441701164_6dbbdf1bce.jpg': ['a dirt bike rider hold up his finger .',
#   'A man wear a sponsor cover motorcycle suit sit on a motorbike raise his hand .',
#   'A motorcycle racer be gesture at somebody .',
#   'A race car driver stand up with his hand point in the air .',
#   'A person in a blue jacket have a colorful helmet on .'],
#  '3442978981_53bf1f45f3.jpg': ['Two fencer be in a bout in a white gym .',
#   'Two fencer practice together ; one jump as the other crouches .',
#   'Two person be fence .',
#   'Two suit fencer point their sword at each other .',
#   'Two sword fighter train .'],
#  '3443351431_7b4061df5c.jpg': ['A bee hover over white flower .',
#   'A black-blue insect fly over a white flower .',
#   'A black insect approach a flower .',
#   'A blue insect be fly near the bloom of a flower plant .',
#   'Bee hover above a flower .'],
#  '3443703471_14845d8850.jpg': ['A dog leap over a barrier .',
#   'A dog leap over a fence .',
#   'A dog leap over a wooden fence as another be about to .',
#   'There be two dog ; one leap over a fence and the other try to .',
#   'Two brown and black dog be jump a fence .'],
#  ...}

# %%
train_image_caption_mapping
# Out:
# {'2513260012_03d33305cf.jpg': ['A black dog be run after a white dog in the snow .',
#   'Black dog chase brown dog through snow',
#   'Two dog chase each other across the snowy ground .',
#   'Two dog play together in the snow .',
#   'Two dog run through a low lie body of water .'],
#  '2903617548_d3e38d7f88.jpg': ['A little baby play croquet .',
#   'A little girl play croquet next to a truck .',
#   'A child be play croquette by a truck .',
#   'A kid be in front of a car with a put and a ball .',
#   'A little boy be play with a croquet hammer and ball beside a car .'],
#  '3338291921_fe7ae0c8f8.jpg': ['A brown dog in the snow have something hot pink in its mouth .',
#   'A brown dog in the snow hold a pink hat .',
#   'A brown dog be hold a pink shirt in the snow .',
#   'A dog be carry something pink in its mouth while walk through the snow .',
#   'A dog with something pink in its mouth be look forward .'],
#  '488416045_1c6d903fe0.jpg': ['A brown dog be run along a beach .',
#   'A brown dog wear a black collar run across a beach .',
#   'A dog walk on the sand near the water .',
#   'Brown dog run on a beach .',
#   'A large brown dog be run on a beach by the ocean .'],
#  '2644326817_8f45080b87.jpg': ['A black and white dog with a red Frisbee stand on a sandy beach .',
#   'A dog drop a red disc on a beach .',
#   'A dog with a red Frisbee fly in the air .',
#   'Dog catch a red Frisbee .',
#   'A black dog be drop a red disc on a beach .'],
#  '218342358_1755a9cce1.jpg': ['A cyclist wear a red helmet be ride on the pavement .',
#   'A girl be ride a bike on a street while wear a red helmet .',
#   'A person on a bike wear a red helmet , ride down a street .',
#   'A woman wear a red helmet and blue shirt as she go for a bike ride in the shade .',
#   'Person in blue shirt and red helmet ride bike down a road'],
#  '2501968935_02f2cd8079.jpg': ['A man dress in a purple shirt and red bandanna smile at person watch him .',
#   'A man on a street wear leather chap and a chainmail codpiece .',
#   'A man wear a purple shirt and black leather chap pose for the camera .',
#   'Man dress in leather chap and purple shirt stand in front of onlooker',
#   'There be a man in a purple shirt , leather chap and a red bandanna , stand near other man .'],
#  '2699342860_5288e203ea.jpg': ['A boy wear a red t-shirt be run through woodland .',
#   'A child run near some tree .',
#   'A young boy be dance around .',
#   'A young boy with a red short sleeved shirt and jean run by some tree .',
#   'A little boy in a red shirt stop to smile for the camera .'],
#  '2638369467_8fc251595b.jpg': ['A girl in a white dress .',
#   'A little girl in white be look back at the camera while carry a water grenade .',
#   'A smile young girl in braid be play ball .',
#   'A young girl wear white look at the camera as she play .',
#   'A girl be hold a green ball .'],
#  '2926786902_815a99a154.jpg': ['A skier in a yellow jacket be airborne above the mountain .',
#   'A skier jump high in the air with a view of the mountain .',
#   'A ski man in a fluorescent jacket jump very high and it look as though he be fly .',
#   'Somone be high in the air do a ski jump .',
#   'A skier in a green jacket and white pants appear to almost fly into the sky .'],
#  '2851304910_b5721199bc.jpg': ['A photographer look over the hill .',
#   'A woman in a red jacket be videotape a natural landscape .',
#   'A woman with a camera look out over roll hill .',
#   'A woman with a camera on a tripod be look at a view .',
#   'Lady in red shirt have her camera set up in the field to record something .'],
#  '3423802527_94bd2b23b0.jpg': ['A bunch of girl in cheerleader outfit .',
#   'a large group of cheerleader walk in a parade',
#   'Cheerleader perform .',
#   'many cheerleader wear black , walk down a street .',
#   'Parade of cheerleader wear black , pink and white uniform .'],
#  '3356369156_074750c6cc.jpg': ['A blue boat with a yellow canopy be float on calm water .',
#   'A boat in the water .',
#   'A boat with a roof on green water .',
#   'A boat be in the middle of the water .',
#   'A solitude boat float on a lake .'],
#  '2294598473_40637b5c04.jpg': ['A dog catch a Frisbee in midair .',
#   'A dog catch a Frisbee .',
#   'A terrier mix catch a Frisbee in the air .',
#   'A white and black dog catch a Frisbee .',
#   'A white dog be leap in the air with a green object in its mouth .'],
#  '1191338263_a4fa073154.jpg': ['A little old lady sit next to an advertise .',
#   'An Asian woman wait at an underground train stop .',
#   'An old woman sit in a transit station next to a backlit advertise .',
#   'A woman sit in a subway station .',
#   'A woman with an umbrella be sit at a station , with an Aquos commercial on the wall .'],
#  '2380765956_6313d8cae3.jpg': ['A blond girl wear a green jacket walk on a trail along side a metal fence .',
#   'A girl in a green coat walk down a rural road play a flute',
#   'A young girl in a parka play a flute while walk by a fenced in field .',
#   'Girl in green and blue jacket walk past an enclosed field .',
#   'Girl play flute as she walk by fence in rural area .'],
#  '3197891333_b1b0fd1702.jpg': ['A family of nine person , include four child , pose in front of a brick fireplace with a white mantle .',
#   'A family pose in front of the fireplace and Christmas tree .',
#   'A family pose by a mantle and christmas tree .',
#   'A happy family pose by a fireplace .',
#   'Two couple and four kid pose for a family picture .'],
#  '3119887967_271a097464.jpg': ['Man in a sweater point at the camera .',
#   'One man be pose with arm outstretched and finger point while another stare from behind him .',
#   'A man in a black hat stand behind a man who be point his finger .',
#   'Two man look toward the camera , while the one in front point his index finger .',
#   'Two man , one wear a black hat while the one in front point , stand in a hallway .'],
#  '2276499757_b44dc6f8ce.jpg': ['A dog look warily at a brown dog investigate his area .',
#   'A large brown dog be look at a medium size black dog .',
#   'A small black dog look at a large brown dog in a grassy field .',
#   'A big brown dog look at a small black dog in tall grass .',
#   'There be a big dog look at a little dog .'],
#  '2506892928_7e79bec613.jpg': ['three child in a field with white flower',
#   'Three child , one with a stuffed kitten , in a field of flower .',
#   'three child play in a garden .',
#   'Three child pose among wildflower .',
#   'Three kid palying with a toy cat in a garden .'],
#  '2187222896_c206d63396.jpg': ['a boy in a red shirt , in front of a long blue wall , raise his eyebrow at the camera',
#   'A boy in a red shirt with stripe stand near a blue , brick wall with handicap sign .',
#   'An African American boy stand in front of a blue building in a handicapped space .',
#   'A boy in an orange shirt look backwards .',
#   'A boy in a red shirt be next to a blue wall .'],
#  '2826769554_85c90864c9.jpg': ['A brown dog be carry a wet stick on the shore of the ocean .',
#   'A dog bound across a sandy beach with a stick in his mouth and water splash off his paw .',
#   'A wet , blond dog carry a stick on the shore .',
#   'A dog be run along a beach next to the ocean with a stick in its mouth .',
#   'A wet , brown dog have a stick in his mouth and be run in the sand next to the water .'],
#  '3097196395_ec06075389.jpg': ['Two dog be race on a ractrack .',
#   'two dog race across a track .',
#   'Two greyhound race',
#   'Two greyhound with muzzle race along the inside curb of a rail dirt track .',
#   'Two race dog run around a track .'],
#  '3603116579_4a28a932e2.jpg': ['A baseball pitcher with Shelton on his shirt throw the ball .',
#   'A baseball player in a black and orange shirt , and with a glove on , pitch the ball .',
#   'A male dress in a sport outfit try to catch a baseball .',
#   'A man play baseball .',
#   'A baseball player be run after the ball .'],
#  '3339263085_6db9fd0981.jpg': ['A brown dog wade through water and walk toward a rock .',
#   'A dog have wade through shallow water to reach a rock outcrop .',
#   'A light brown dog be splash in the water with its paw .',
#   'A small brown dog be about ready to exit the water after a swim .',
#   'A yellow dog in shallow water .'],
#  '2532262109_87429a2cae.jpg': ['A group of 5 girl in school uniform be stand together and wait to cross a street while one girl take a picture .',
#   'A group of person be stand together outside as one take a photograph .',
#   'A group of school girl be stand together while one be take picture .',
#   'A group of young woman stand together .',
#   'Girl in school uniform .'],
#  '2076906555_c20dc082db.jpg': ['A boy wear a jean jacket with his hand on his chest smile at the camera .',
#   'a boy with a bruised nose and writing on his hand be stand in a video rental store .',
#   'A boy with writing on his hand be stand in a store .',
#   'A young man in a jean jacket smile for the camera inside a store .',
#   'A young man with a denim jacket and writing on his hand smile in front of a bookcase full of video .'],
#  '2502007071_82a8c639cf.jpg': ['A group of person in front of a house .',
#   'A man in stripe , a woman in sunglasses , and a child in a blue hat in front of a brick building .',
#   'A woman in sunglasses and a blue flowered shirt stand while a boy and a man sit nearby .',
#   'A woman wear sunglasses and a flower shirt look to the left .',
#   'Three adult and one child be wait outside of a building , perhaps a school .'],
#  '3113769557_9edbb8275c.jpg': ['A woman stand in front of a display case and another woman look at a digital camera',
#   'A woman stand tall in front of a glass display while another woman take a picture of something .',
#   'A woman stand with her arm out at her side while another take a picture .',
#   'A woman stand with her arm out in a store while another woman hold a camera .',
#   'One woman be take a picture and another woman be stand sideways with her arm out .'],
#  '3325974730_3ee192e4ff.jpg': ['A snowboarder jump high into the air off of a snowy ramp .',
#   'A snowboarder jump off a ramp .',
#   'Man on a snowboard perform a trick high in the air .',
#   'Person in a purple coat make a jump on a snowboard .',
#   'Snowboarder jump off high ramp over icy landscape .'],
#  '1655781989_b15ab4cbff.jpg': ['A group of mountain climber',
#   'A group of person walk in a line through the snow toward a mountain .',
#   'A line of person be make their way through snow cover mountain .',
#   'People be walk through a snow cover field with a mountain the background .',
#   'People face mountain in the snow .'],
#  '1662261486_db967930de.jpg': ['A black and white dog be jump through a black and white hoop .',
#   'A black and white dog jump through a black and white hoop .',
#   'A brown and white dog jump through a black and white hoop .',
#   'A dog jump through a black and white hoop .',
#   'A dog jump through a ring .'],
#  '2410562803_56ec09f41c.jpg': ['A girl use a laptop , another girl , and a boy look at his cellphone .',
#   'A group of person sit against a building and use electronics .',
#   'Three person sit near a street .',
#   'Three person sit in front of a store on a bench .',
#   'Three young person sit outside and engage with electronic device .'],
#  '2469498117_b4543e1460.jpg': ['A dog race while wear number 6 .',
#   'A greyhound wear a muzzle and the number six on a yellow jacket be run on a dog track .',
#   'a muzzle greyhound dog run on a track',
#   'A tan greyhound wear a gold shirt with a number on it run down a track .',
#   'muxzzled greyhound leap in race with yellow jacket .'],
#  '69710415_5c2bfb1058.jpg': ['A group of person stand at the edge of a cliff over the ocean .',
#   'A group of three boy scout rest on a bluff overlook the ocean .',
#   'Three man stand on a cliff overlook a lake .',
#   'Three scout be on top of a cliff overlook the ocean .',
#   'Two man be sit on a rock near the ocean with another man stand nearby .'],
#  '3414734842_beb543f400.jpg': ['A couple hold hand and another woman be walk down a wooded trail .',
#   'A couple hold hand and a woman stand beside them pose on a tree line dirt road .',
#   'Three friend on a stroll in a forest .',
#   'Three person stand on a path through the wood .',
#   'Two woman and a man pose on a rural path'],
#  '3006217970_90b42e6b27.jpg': ['A car sponsor by Riwal be smoke its tire on a wet road .',
#   'A race car drive along a track in the rain',
#   'A race car be drive around a wet track with its headlight on .',
#   'A small race car with advertise be drive on a rainy track .',
#   'A sponsored race car be drive with light on a wet raceway .'],
#  '2192411521_9c7e488c5e.jpg': ['A bearded man wear a bandanna be point his finger whilst ride a bicycle .',
#   'A man bicycle down a street and point his finger',
#   'A man hold an object with his hand while ride his bike down a street .',
#   'A man with long hair ride a bicycle give a peace sign .',
#   'Man in blue shirt and black cap ride bike down street flash peace sign'],
#  '3535879138_9281dc83d5.jpg': ['A crowd of person wave red flag be pass under a bridge .',
#   'A group of person walk down a street carry red flag .',
#   'A large group of person walk down a street , some carry flag or banner .',
#   'Many person walk together on pavement near a brick building with other person look on .',
#   'many person walk in a street .'],
#  '2685788323_ceab14534a.jpg': ['A man in sunglasses get ready to pull a chair out to sit down for his meal .',
#   'A man wear sunglasses stand by a table at a cafe .',
#   'Man about to pull out chair and sit down at a restaurant .',
#   'Man at eatery get ready to sit down .',
#   'Large man grab a seat at a restaurant .'],
#  '3465606652_f380a38050.jpg': ['A boy hold a racket be stand in the grass .',
#   'A boy in a purple shirt and blue jean be stand in the grass hold a round toy with a handle .',
#   'A boy play with a stringless racket in his backyard .',
#   'a boy walk through a lawn .',
#   'A child in purple clothing be play with a toy inside a yard with other toy and a fence .'],
#  '2599131872_65789d86d5.jpg': ['Two blond girl be play together .',
#   'Two girl enjoy themselves whilst wind blow through their hair .',
#   'Two girl with long hair jump on a trampoline .',
#   'Two little blond girl twirl their hair .',
#   'Two little girl be play on a trampoline .'],
#  '2244613488_4d1f9edb33.jpg': ['Four bicyclist ride along a dirt road between two wire fence .',
#   'Four cyclist on a country trail be pass by an electricity pylon .',
#   'Four bicyclist be ride through the desert .',
#   'three biker bike across the dry land .',
#   'Three cyclist ride near mountain .'],
#  '2738077433_10e6264b6f.jpg': ['A dog climb a steep dirt hill .',
#   'A dog climb a hill .',
#   'a great Dane climb a steep hill',
#   'A light brown dog be run up .',
#   'A light dog climb a wall of dirt .'],
#  '3537201804_ce07aff237.jpg': ['A child spin on a merry-go-round .',
#   'Childern be play on a merry go round as adult on a bench watch them .',
#   'child play on a merry-go-round as adult look on from a bench .',
#   'Father watch as their child enjoy a spin merry-go-round .',
#   'Two kid sit in the middle of a playground toy that spin around them .'],
#  '1597557856_30640e0b43.jpg': ['a brown dog be jump up at a woman who be wear a brown skirt .',
#   'A golden retriever be excitedly greet a woman as a little dog walk towards the camera .',
#   'A tan dog jump up at a woman in a skirt and a black and tan dog walk away .',
#   'A yellow dog jump to greet a woman .',
#   'One dog be jump at a lady while the other walk away .'],
#  '3357194782_c261bb6cbf.jpg': ['A man in the dooorway of a bus look onward .',
#   'A man stand at the door of a vehicle , with another sit , glance out a window .',
#   'People ride a bus or trolley .',
#   'some person ride an old bus',
#   'Three passenger on a train car .'],
#  '3682038869_585075b5ff.jpg': ['A little girl be peak out from behind a tree .',
#   'A little girl peer out from behind a tree .',
#   'A young girl hide behind a tree in a forest .',
#   'A young girl peek out from behind a tree in a wooded area .',
#   'A young girl wear a striped dress peek out from behind a tree .'],
#  '236474697_0c73dd5d8b.jpg': ['A group of person hold drink and point at the camera .',
#   'A group of person be hold up drink and point to the camera .',
#   'A group of young person hold bottle and point at the camera .',
#   'several young person pose for this photo hold beer',
#   'Young adult stand point at a person take a picture .'],
#  '2641288004_30ce961211.jpg': ['A border collie jump over a bed with a tennis ball in its mouth .',
#   'A dog jump with a ball in its mouth .',
#   'A dog jump on a bed and catch a green toy .',
#   'Border collie jump in the air and catch a tennis ball .',
#   'Black and white dog jump with a tennis ball in its mouth .'],
#  '267164457_2e8b4d30aa.jpg': ['A climber walk along a snowy peak .',
#   'A man climb over snow cover rock by a shore .',
#   'A man be stand on a snowcapped mountain .',
#   'A person hike down a snowy mountain .',
#   'There man on top of an snow cover mountain with a lake behind him .'],
#  '2453891449_fedb277908.jpg': ['A white dog chase a black dog across the grass .',
#   'A white dog be follow a black dog through a grassy area .',
#   'There be two dog , black and white , and a black one be jump .',
#   'Two dog run in a grassy , fence in area surround by tree .',
#   'Two dog run through a yard with a forest in the distance .'],
#  '281419391_522557ce27.jpg': ['A black race car spin its tire while smoke come out .',
#   'A black race car start up in front of a crowd of person .',
#   'A break down car during a race',
#   'Race car smoke very badly on a racetrack .',
#   'Red Bull-branded race car leave smoke behind it in front of a crowd .'],
#  '354999632_915ea81e53.jpg': ['A person behind some bag inside an igloo .',
#   'a snowy cave full of luggage',
#   'Inside an igloo , a young man get ready for his overnight stay .',
#   'Some backpack pile up in an ice cave with a person dress in black in the background .',
#   'There be something visible through a hole in the wall .'],
#  '3109136206_f7d201b368.jpg': ['A brown dog drink from a body of water .',
#   'A brown dog be start to walk into water .',
#   'A brown dog step into murky water .',
#   'A dog get into some water .',
#   'A dog put his leg into a pond'],
#  '2281054343_95d6d3b882.jpg': ['A man wear a black hat be walk through a busy city street .',
#   'A silhouette of a man in a hat on a busy city street .',
#   'Person with black hat and black coat near building with sign .',
#   'Three person in a crowded city area .',
#   'Thre be a shot of man with his back turn in a city .'],
#  '3296584432_bef3c965a3.jpg': ['A brown dog chase something a man behind him throw on a beach .',
#   'A man and a dog on a beach .',
#   'A man be interact with a dog that be run in the opposite direction .',
#   'A man play fetch with his dog on a beach .',
#   'A man walk behind a run dog on a beach .'],
#  '3526431764_056d2c61dc.jpg': ['A woman take a photo stand next to a tall man and in front of another man who be also take a photo .',
#   'Three person be outdoors take picture .',
#   'Three person hold camera be stand on a dirt trail with grass on the side of it .',
#   'Three person take picture with their camera',
#   'Two person be take picture while a third be hold a camera .'],
#  '3549997413_01388dece0.jpg': ['A man be ski down a mountain with another large mountain behind him and a river between the mountain .',
#   'A man be ski down a snowy hill with a large mountain in the background .',
#   'A man ski down a snow cover mountain .',
#   'A person ski down a snowy mountain .',
#   'A skier go down a hill with a mountain as a backdrop .'],
#  '143688895_e837c3bc76.jpg': ['A boy climb a rock face',
#   'A climber be stand on the rock face next to a pink rope .',
#   'A man climb a cliff with a rope .',
#   'A man climb steep rock .',
#   'A man rock climb in a forest surround by light .'],
#  '2495394666_2ef6c37519.jpg': ['A brown dog be stand in a lake .',
#   'A brown dog be swim in a creek .',
#   'A dog swim in a pond',
#   'Dog swim in body of water',
#   'A brown dog be swim in the water .'],
#  '3384742888_85230c34d5.jpg': ['A dog play with a toy in the grass .',
#   'A rotweiler playful roll over int he grass with a toy .',
#   'Black and tan dog play with a toy and roll on the grass .',
#   'Dog chew up ball while roll in grass',
#   'A dog be rest after a game of fetch .'],
#  '1160034462_16b38174fe.jpg': ['A elderly man in a straw hat be sit on a bench .',
#   'a elderly man sit alone on a park bench .',
#   'An old man in a straw hat sit on a park bench .',
#   'An old man in a brown hat be sit on a bench .',
#   'White haired man in gray sweater and a straw hat sit on a bench under a tree .'],
#  '334768700_51c439b9ee.jpg': ['A dark-haired man in a red t-shirt , with a beard , play a guitar in a park .',
#   'A man in a red shirt play guitar in a park .',
#   'A man be sit and play guitar on the grass .',
#   'a man sit in the grass , play his guitar , wear a red shirt',
#   'a man wear red play his guitar on the grass .'],
#  '412101267_7257e6d8c0.jpg': ['Two black dog be jump and play with a yellow tennis ball in the snow .',
#   'Two dog play in the snow .',
#   'Two dog , one with a tennis ball in his mouth , play together in the snow .',
#   'Two dog play with a ball in the snow .',
#   'Two dog play with a tennis ball in the snow .'],
#  '2623939135_0cd02ffa5d.jpg': ['An attractive woman hold a halo above her head .',
#   'A woman in a dress raise her arm over her head .',
#   'A woman be look at the ceiling while take off her hat .',
#   'A woman look up towards a wide ring , she be hold over her head , a drink in her other hand .',
#   'A woman look upward with her hand above her head .'],
#  '3043266735_904dda6ded.jpg': ['An elderly person with a white hat be read a paperback book .',
#   'An elder woman in a hat and scarf be look through a book she have in her hand .',
#   'An old woman wear a hat read a book .',
#   'An old lady consult a paperback book .',
#   'A woman in a white hat read a book .'],
#  '3034585889_388d6ffcc0.jpg': ['A looker on catch a motocross bike on its side after a spill while another race by .',
#   'A man on a dirt bike zip away while another one slip to the ground and a third man in a yellow jacket look on .',
#   'A man on a motorcycle make a tight turn',
#   'A person be ride their motorbike and a person in a bright yellow jacket be watch someone fall off their bike .',
#   'Bike rider be look at a accident of other sport bike rider .'],
#  '2069279767_fb32bfb2de.jpg': ['Men be climb .',
#   'Two man be lie in red cot on the side of a mountain .',
#   'Two man be sleep on makeshift bed on the side of a cliff .',
#   'Two man in cot hang from a cliff',
#   'Two mountain climber be smile on a mountainside .'],
#  '2593406865_ab98490c1f.jpg': ['A skateboarder jump off his skateboard in midair in hope of land back on it .',
#   'A teenage boy be perform a trick with his skateboard .',
#   'A young man be flip a skateboard during a trick .',
#   'a young skateboarder do trick in the air',
#   'A man be perform a trick on a skateboard near onlooker .'],
#  '432167214_c17fcc1a2d.jpg': ['A dark colored man be hold a protest banner in a busy city street with person stare from behind .',
#   'A man in a blue and yellow jacket hold a religious sign stand in a street with person behind him on a sidewalk .',
#   'A man be hold a religious poster .',
#   'A man wear a hat hold a sign with writing on it .',
#   'Man stand on a street hold a sign'],
#  '305749904_54a612fd1a.jpg': ['A man be wear a blue shirt with a word Mambo on it .',
#   'A man be wear a shirt that read , " Mambo " with an image of a baby and a teddy bear .',
#   'A man wear a t-shirt show a baby hump a stuffed bear .',
#   'A person wear a blue mambo shirt have his back to the camera .',
#   'A man be wear a blue shirt .'],
#  '2780087302_6a77658cbf.jpg': ['A man in black shirt sit on a stool while try to sell stuffed animal .',
#   'A man be outside sell various toy .',
#   "A vendor sell child 's toy as visitor walk by .",
#   'A vendor sell inflatable toy and stuff animal on a sidewalk .',
#   'Man sit on stool beside toy .'],
#  '3051998298_38da5746fa.jpg': ['A guy in navy blue and yellow short jump into a pool .',
#   'A man catch a football in midair while jump into a pool .',
#   'A man in swim trunk be jump into a pool while in a strange pose',
#   'Antic in a covered pool .',
#   'People be dive into a swim pool .'],
#  '1574401950_6bedc0d29b.jpg': ['A boy jump from the top of a blue plastic slide .',
#   'A child jump over the slide portion of playground equipment shade by tree .',
#   'A little boy in a striped shirt jump from a blue slide .',
#   'A little boy be jump off the top of a slide .',
#   'A young boy jump on a slide in a backyard .'],
#  '539493431_744eb1abaa.jpg': ['A man be play with a fire baton in the day light .',
#   'A man juggle fire .',
#   'A man stand near a playground .',
#   'Man throw flame outside .',
#   'A guy be hold a black stick in front of a playground .'],
#  '3524436870_7670df68e8.jpg': ['A brown dog play with bubble .',
#   'A brown dog walk across a lawn as bubble float by .',
#   'A dark brown dog be look at bubble while walk on green grass .',
#   'Dog catch bubble on the grass .',
#   'A brown dog be chase and pop bubble .'],
#  '2081446176_f97dc76951.jpg': ['A guy with a scarf and weave toboggan .',
#   'A man in black and white cap and scarf .',
#   'A man wear a scarf and knit hat be smile .',
#   'A person wear a hat and scarf look to the right .',
#   'A man have a poof on top of his woolen hat .'],
#  '2265367960_7928c5642f.jpg': ['A boy sit down smile for a picture .',
#   'A child hold some shoe .',
#   'A child in blue and wear a hat smile .',
#   'A young boy smile and hold sandal .',
#   'A boy be wear a hat and hold sandal .'],
#  '460350019_af60511a3b.jpg': ['A black dog and a woman in a red shirt play tug of war .',
#   'A dog be pull on one end of a rope and a girl be pull on the other .',
#   'A woman play tug-of-war with her black dog in a brown landscape surround by tree .',
#   'A woman play with her rottweiler dog outside .',
#   'A woman and a dog play outside'],
#  '2976946039_fb9147908d.jpg': ['A group of person surf on a very large wave .',
#   'a group of surfer catch a wave',
#   'People surf and attempt to surf in the ocean on a big wave .',
#   'Several person be surf on a wave in the sea .',
#   'Surfer on a huge ocean wave at sunset .'],
#  '2308108566_2cba6bca53.jpg': ['A man ride a bike on a dirt path .',
#   'A person bike through the wood .',
#   'A person dirtbikes along a muddy trail .',
#   'Dirt bike rider ride down a slope .',
#   'Person ride a dirt bike down a dirt hill .'],
#  '3367758711_a8c09607ac.jpg': ['There be two woman crossing a street in front of two bus .',
#   'Two woman in headwraps be hurry past bus .',
#   'Two woman walk in front of a bus to cross a road .',
#   'Two woman walk on a street in front of two bus .',
#   'Two woman with their head cover crossing a road in front of bus .'],
#  '3666056567_661e25f54c.jpg': ['A group of person walk down a city street at night .',
#   'A group of person walk down a street with one on the phone in a green hat .',
#   'Four person be walk along a city sidewalk , while the one in green hat talk on a cellphone .',
#   'Four person be walk on a sidewalk .',
#   'four person walk down a sidewalk at night'],
#  '3099264059_21653e2536.jpg': ['A skateboarder be jump almost as high as a building .',
#   'A snowboarder jump off a tall brick building .',
#   'a snowboarder jump over a pile of snow .',
#   'Snowboarder jump off rail over snowpile .',
#   'A snowboarder be do a stunt high in the air at night .'],
#  '2988439935_7cea05bc48.jpg': ['A man in a red soccer uniform get ready to kick the ball .',
#   'A man in a red uniform play in a soccer game .',
#   'A man in a red uniform run towards a soccer ball on a field .',
#   'A player in a red uniform get ready to kick the ball during a soccer match , as a crowd watch .',
#   'A soccer player in red uniform run after a soccer ball .'],
#  '241345864_138471c9ea.jpg': ['A boy cheerleader have a girl cheerleader on his knee .',
#   'A female cheerleader sit on the knee of a male cheerleader .',
#   'cheerleader take a break',
#   'A cheerleader in red and white be sit on the knee of a man also wear red and white .',
#   'Two cheerleader be sit at a football game .'],
#  '3019199755_a984bc21b1.jpg': ['A driver be at the wheel of a race car .',
#   'A man inside a red race car give a thumb up sign .',
#   'A man be in a red race car while another man be at the back of it .',
#   'A man be smile whilst sit inside a red race car .',
#   'A race car driver smile and give thumb up before a race .'],
#  '3201594926_cd2009eb13.jpg': ['A girl wear white polka dot and black boot walk and a woman in a blue outfit hurridly walk behind her .',
#   'A hip young woman down a street with a woman in a kimono walk behind her .',
#   'A woman in boot with a big purse walk down a street follow by a woman in blue .',
#   'a woman walk with her big purse .',
#   'Woman walk down a street .'],
#  '2540751930_d71c7f5622.jpg': ['A man and woman walk away from the camera as a redheaded man walk in the other direction .',
#   'Pedestrian walk on a sidewalk next to a grassy , wooded field .',
#   'People be walk around a park area .',
#   'People meander around in a grassy area with tree .',
#   'Young adult dress casually walk around in a field .'],
#  '1475046848_831245fc64.jpg': ['A blond woman in blue short walk on a beach carry her shoe .',
#   'A woman in blue short be carry her shoe whilst walk on a beach next to the ocean .',
#   'Blond woman with blue short walk along beach carry shoe in one hand .',
#   'Woman carry her shoe on a beach .',
#   'Woman in blue short walk barefoot on a beach'],
#  '2877637572_641cd29901.jpg': ['A cute puppy fetch a yellow ring chew toy in the yard .',
#   'A puppy be run across the grass with a yellow toy in its mouth .',
#   'A tan dog be run through the grass with a yellow toy in its mouth .',
#   'A tan dog with a red collar run with a yellow toy in its mouth .',
#   'Fluffy golden puppy hold yellow ring in mouth while run through grass'],
#  '1308472581_9961782889.jpg': ['a boy in blue shirt splash in water under a dock',
#   'A laugh girl hold a bucket splash in the ocean',
#   'A young girl play under a pier with a blue bucket .',
#   'Girl with a blue bucket be play and splash in the ocean water .',
#   'A girl with a blue bucket splash beneath a pier .'],
#  '2282260240_55387258de.jpg': ['A little girl dance in a room with balloon on the floor .',
#   'A young girl dance in her sock on a wooden floor strew with pink balloon .',
#   'Child with pink string on head dance surround by confetti , balloon .',
#   'Little Girl in brown shirt and bluejean skirt dance on wood floor .',
#   'A blond girl be dance inside a house .'],
#  '2363419943_717e6b119d.jpg': ['A lady and her little girl be hold hand and walk up a sidewalk .',
#   'A mother and child run hand in hand through Chinatown in an American City .',
#   'a woman and a child both wear red outfit walk up a street',
#   'Child in red hold the hand of person in red coat walk on sidewalk under awning .',
#   'woman and little girl wear red in Asian area'],
#  '392976422_c8d0514bc3.jpg': ['a boy in a blue shirt be walk along a tan and blue wall',
#   'A boy in stripe walk along a ledge .',
#   'a boy scale the wall .',
#   'A child in a striped shirt be walk along a wall .',
#   'Boy in striped t-shirt walk along a ledge .'],
#  '103205630_682ca7285b.jpg': ['A tent be be set up on the ice .',
#   'Two man be about to enter an ice fish tent on a snow cover lake .',
#   'two man set up a blue ice fish hut on an iced over lake',
#   'Two man , stand on an ice , look into something cover with a blue tarp .',
#   'Two person stand outside a blue tent structure on a snowy surface .'],
#  '1347519824_e402241e4f.jpg': ['A few girl with green foam statue of liberty hat on a train',
#   'Some young adult be wear green foam statute of liberty crown .',
#   'Some young person take photo of each other while in New York .',
#   'Three woman with statue of liberty hat and take a picture .',
#   'Two woman wear statue of liberty hat get their picture take in a subway .'],
#  '584484388_0eeb36d03d.jpg': ['Two brown dog be play with a red ball .',
#   'Two brown dog fight over a red ball while play in the grass .',
#   'Two brown dog run over the grass carry a red toy .',
#   'Two daschunds play with a red ball',
#   'Two little wiener dog be run on the grass carry a red ball between them .'],
#  '2460823604_7f6f786b1c.jpg': ['A boy baseball player in a green and yellow jersey leap for the ball .',
#   'A boy chase a baseball .',
#   'A little boy play baseball go for the ball on the ground .',
#   'A young boy dive to catch the ball during a baseball game .',
#   'A boy in a green and yellow shirt have a glove on and be go towards the ball .'],
#  '121800200_bef08fae5f.jpg': ['A group of climber begin up a sheer rock face .',
#   'A group of rock climber climb a rock wall in a forest .',
#   'Many person be climb a mountain surround by pretty green tree .',
#   'People at a distance try to climb a cliff .',
#   'The flat side of a large , rocky mountain .'],
#  '2422302286_385725e3cf.jpg': ['A child sit in a plastic toy car .',
#   'A little kid in a toy car .',
#   'Small girl ride in play car .',
#   'There be a child in a red and yellow toy car .',
#   'A small child be sit in a red and yellow toy car .'],
#  '3183883750_b6acc40397.jpg': ['two girl hold up a card read " know what this be " ?',
#   'Two kid smile and hold a card .',
#   'Two person pose for a picure hold a card that say " know what this be ? "',
#   'Two person smile at the camera while hold a sign .',
#   'Two teenage girl hold a card refer to period as they smile .'],
#  '3091912922_0d6ebc8f6a.jpg': ['A dog run hold a yellow dog toy in fall , bench in the background .',
#   'A dog run with a yellow toy in its mouth .',
#   'a tan dog run through the grass with a toy in his mouth .',
#   'A brown dog be run through the grass with a yellow toy in its mouth .',
#   'A tan colored dog have a yellow toy in its mouth .'],
#  '2787868417_810985234d.jpg': ['a blond girl in a pink bathe suit run through sprinkler',
#   'A girl in pink run through a sprinkler .',
#   'A girl run through sprinkler on a lawn .',
#   'A little girl in pink in run through a sprinkler .',
#   'A little girl wear a pink dress be run across the grass .'],
#  '3670075789_92ea9a183a.jpg': ['A child be slide into a small pool .',
#   "A girl in a child 's swim pool .",
#   'a little girl be slide down a short slide into an inflatable paddle pool .',
#   'Girl splash in kiddie pool',
#   'A dark-haired girl be slide into a white kiddie pool .'],
#  '3329169877_175cb16845.jpg': ['A lone snowboarder wear a white jacket jump into the air on the snowy mountain .',
#   'A snowboarder fly through the air in front of leafless tree .',
#   'a snowboarder get some air .',
#   'A snowboarder in green pants and a white jacket be jump high in the air .',
#   'Someone in green pants be on a white snowboard in the air .'],
#  '751074141_feafc7b16c.jpg': ['A boy be pull on a shovel .',
#   'A happy child play in the scoop of a shovel by a chair in a grassy backyard .',
#   'A little boy in red flowered short be sit on a shovel .',
#   'A little boy smile and ride in a shovel .',
#   'Small boy in red short with blue flower sit on shovel in the grass near a tan chair .'],
#  '3445428367_25bafffe75.jpg': ['A person be stand on a brick ledge take a picture of something in the distance .',
#   'A woman take a photograph .',
#   'A woman with long hair point her camera skyward as she stand on a brick wall .',
#   'A woman be hold a camera and stand on a brick wall .',
#   'Woman stand on a brick wall and take a picture'],
#  '3542418447_7c337360d6.jpg': ['A black dog and a brown dog with a yellow foam soccer ball toy on a grassy field',
#   'A brown dog and a black dog play with a yellow soccer ball .',
#   'Two dog on a lawn play with a plastic toy , in a distorted photograph .',
#   'Two dog , one brown one black with a yellow toy , black dog have mouth open and brown dog have a toy .',
#   'Two dog run to catch a yellow soccer ball .'],
#  '2730819220_b58af1119a.jpg': ['a little girl end up at the bottom of a slide .',
#   'a little girl be just reach the bottom of a playground slide',
#   'A little girl land at the bottom of a slide .',
#   'A young girl reach the bottom of a slide .',
#   'a young girl slide down a tan plastic slide'],
#  '3543378438_47e2712486.jpg': ['A man dress in a green jacket be play piano while a woman sing .',
#   'A man be sit in front of a harpsichord , and a woman be prepare to sing .',
#   'A person play a piano with a singer nearby .',
#   'A pianist and a singer be ready to perform .',
#   'A man in a green jacket be play a piano next to a woman who be by a music stand .'],
#  '2335619125_2e2034f2c3.jpg': ['A big black dog bare its teeth while run through the snow .',
#   'A black dog be run through the snow .',
#   'A black dog be run through the snow .',
#   'A black dog with his mouth open and tongue out run across an expanse of snow .',
#   'Black dog run through snow .'],
#  '3520199925_ca18d0f41e.jpg': ['A curly haired woman play a violin .',
#   'A red haired woman be hold a violin and boe .',
#   'A woman be play a violin while surrounded by transparent wall and picture .',
#   'A woman play a violin with poster in the background .',
#   'A woman be hold a violin .'],
#  '3374722123_6fe6fef449.jpg': ['An elderly woman be wear a pink striped shirt .',
#   'an old woman in a pink striped shirt',
#   'An old woman with a striped shirt rub her chin .',
#   'A woman in a pink striped shirt , with her hand up .',
#   'Old lady be appear to be get ready to cover her mouth .'],
#  '3280672302_2967177653.jpg': ['a boy carry a teenager on his back .',
#   'A boy struggle to carry a girl on his back .',
#   'A person wear a black shirt be get a piggyback ride from a person wear a black t-shirt walkng on a paved path in the wood .',
#   'A teenage boy give another teenage boy a piggy back ride in a forest .',
#   'A boy be carry the other boy .'],
#  '3073579130_7c95d16a7f.jpg': ['a man wear a red bandanna',
#   'A man with a head cover .',
#   'An man wear an Arab scarf , with another man in the background .',
#   'A white man in a turban .',
#   'Man with facial hair wear red and white Palestinian style headscarf .'],
#  '99679241_adc853a5c0.jpg': ['A gray bird stand majestically on a beach while wave roll in .',
#   'A large bird stand in the water on a beach .',
#   'A tall bird be stand on the sand beside the ocean .',
#   "A water bird stand at the ocean 's edge .",
#   'A white crane stand tall as it look out upon the ocean .'],
#  '3759492488_592cd78ed1.jpg': ['A boy hang onto a pole .',
#   'A kid in a green shirt play in a park',
#   'A little kid swing on a pole at a playground .',
#   'A boy in green shirt swing with one arm on a silver pole .',
#   'A boy be swing on a pole at a beach .'],
#  '2875528143_94d9480fdd.jpg': ['a girl wear pink bounce on a bed',
#   'A little girl in a pink leotard be jump and land in a straddle split on a blue bed .',
#   'A young girl jump with her mouth open .',
#   'Little girl in a pink Hello Kitty shirt be jump .',
#   'A girl in pink do a midair leg split .'],
#  '1052358063_eae6744153.jpg': ['A boy take a jump on his skateboard while another boy with a skateboard watch .',
#   'A child be perform a skateboard trick while another child with a skateboard lean on a wall .',
#   'A little boy skateboarder be do a trick on his board while another young skateboarder watch .',
#   'a young boy skateboarder jump on a platform on a skateboard .',
#   'Two skateboarder .'],
#  '111766423_4522d36e56.jpg': ["A black and white bird eat seed out of someone 's hand",
#   'A black and white bird stand on a hand .',
#   "A small bird sit in a person 's hand and eat seed .",
#   'Black and white bird stand on hand of someone hold sunflower seed',
#   'A small bird be cling to a finger of the hand hold seed .'],
#  '2474918824_88660c7757.jpg': ['A guy try to climb a stone cliff while his friend help him .',
#   'A man in a red shirt climb a rock while another man stand behind to help him .',
#   'A man in a red shirt be learn how to climb a cliff .',
#   'A man in brown be help a man in red climb a rock .',
#   'A man wear a brown sweatshirt help a man in red climb a rock .'],
#  '3697675767_97796334e4.jpg': ['A bicycle rider fly over a hill while a competitor be not far behind .',
#   'A dirt bike racer jump off a hill with another racer not far behind .',
#   'A motocross rider be slightly airborne on a competition circuit jump .',
#   'A person be ride a dirt bike in a race on a dirt track .',
#   'Dirtbike rider jump over a hill of a racetrack .'],
#  '241346317_be3f07bd2e.jpg': ['A crowd be stand and cheer at a football game .',
#   'A crowd of person watch a football game with a player wear red and cheerleader also wear red .',
#   'A football player be grab the ankle of another player who be hold the ball .',
#   'An Oklahoma football player be about to score .',
#   'Fan at a football game cheer while a player run towards an endzone .'],
#  '2694178830_116be6a6a9.jpg': ['An athlete perform a high jump .',
#   'A woman athlete launch herself over a bar during a pole vault .',
#   'A woman be black be pole vault .',
#   'A woman pole vaulter upside down as she attempt a vault .',
#   'a woman with her feet in the air about to do pole vault'],
#  '513116697_ad0f4dc800.jpg': ['a lone skier jump on the side of a snowy mountain .',
#   'a skier jump over a gap .',
#   'A skier do a flip while jump .',
#   'A skier do a flip .',
#   'A skier do a high flip over snow in the mountain .'],
#  '371364900_5167d4dd7f.jpg': ['A black and brown dog be jump on block of concrete in the water .',
#   'A black dog careful cross over some water .',
#   'Black dog look at his reflection in the water .',
#   'Black dog near a dock look into murky water',
#   'Black dog jump on a cinderblock .'],
#  '2860041212_797afd6ccf.jpg': ['a black dog have catch a bird in its mouth .',
#   'A black dog in tall grass with a bird in its mouth .',
#   'A black dog stand in a field be hold a bird in his mouth .',
#   'Black retriever stand in the grass , hold a bird in its mouth .',
#   'A black dog in the field have something in its mouth .'],
#  '1481062342_d9e34366c4.jpg': ['A little girl in pajama run down a hall with hardwood floor .',
#   'A little girl be run down a hardwood floor hallway .',
#   'A little girl run down a brighly lit hallway .',
#   'A toddler be run down a hallway .',
#   'A young girl run down a hallway with wooden floor .'],
#  '3556792157_d09d42bef7.jpg': ['A bunch of child sit in chair and stand on wooden floor .',
#   'A group of child sit , stand , and kneel along a wall .',
#   'A group of child sit on fold chair and play .',
#   'a young group of child sit in a row against the wall .',
#   'Kid talk while sit on a row of chair along the wall .'],
#  '3226254560_2f8ac147ea.jpg': ['A dog in a snowy area .',
#   'A spotted dog catch a ball on a snowy field .',
#   'A white and brown spot dog run along the snow to catch a ball .',
#   'A white dog be run fast on a trail cover by snow .',
#   'A brown and white dog be play in the snow .'],
#  '2252123185_487f21e336.jpg': ['A bunch on person be seat in a stadium .',
#   'A crowded stadium be full of person watch an event .',
#   'A crowd of person fill up a pack stadium .',
#   'A crowd sit in an indoor stadium .',
#   'A stadium full of person watch a game .'],
#  '2353088412_5e5804c6f5.jpg': ['A black dog run with a stuffed bird in its mouth and another dog chase it .',
#   'A brown dig and black dog be play with a stuffed toy .',
#   'A brown dog with a toy duck in its mouth run through snow while a black dog chase it',
#   'Dog run with pet toy be chase by another dog .',
#   'A brown dog be be chase by a black dog while hold a small toy in his mouth .'],
#  '3359587274_4a2b140b84.jpg': ['A man ski while wear a parachute .',
#   'A parachute skier lift off from the ground .',
#   'A person attach to a parasail and wear equipment on his feet be suspend in midair over a snowy landscape , while silhouette against a sunny , blue sky .',
#   'A person glide on a parachute in the air .',
#   'They be glide through the air , back by a low sun .'],
#  '3588417747_b152a51c52.jpg': ['A man skateboard on the side of step',
#   'A man slide down a railing while another shine a light on him .',
#   'A person take a picture of someone skate down a railing at night .',
#   'A skateboarder slide down a stair rail in the dark .',
#   'a young man sliiding down a railing near some stair'],
#  '1055623002_8195a43714.jpg': ['A group of four child wear pajama have a pillow fight .',
#   'A group of kid have a pillow-fight .',
#   'A group of young child play pillow fight on a bed .',
#   'child have a pillow fight .',
#   'Four child be have a pillow fight .'],
#  '3454315016_f1e30d4676.jpg': ['A large , white bird skate across the top of some water .',
#   'A white bird with a long neck fly low over the water',
#   'Large white bird graze the water .',
#   'White bird in water prepare to fly .',
#   'White bird start to take flight from a lake .'],
#  '2837808847_5407af1986.jpg': ['A brown a dog and a black dog in the edge of the ocean with a wave under them boat be on the water in the background .',
#   'Two dog , one brown and the other black , play in the surf in the shallow ocean water .',
#   'Two dog play in the wave .',
#   'two dog play in the water .',
#   'Two dog stand back to back in the ocean .'],
#  '3544803461_a418ca611e.jpg': ['A black man in white short and a white man in black short box .',
#   'Black and white man box .',
#   'Two boxer be fight .',
#   'Two man box .',
#   'Two man box in a match .'],
#  '3046916429_8e2570b613.jpg': ['A woman hold a baby and make face at it .',
#   'A woman hold a baby up and make a funny face',
#   'A woman make face at a small child .',
#   'A man wear glasses hold a baby wear blue .',
#   'A woman be make face at a baby that she be hold .'],
#  '2570559405_dc93007f76.jpg': ['Dog be behind a fence .',
#   'Three dog be behind a rusty fence as one bark .',
#   'Two dog be in a fence and one be bark .',
#   'Two dog be look through a rusty wire fence .',
#   'two dog bark behind a fence .'],
#  '2518219912_f47214aa16.jpg': ['A little girl hold a water hose for a dog to drink from .',
#   'A little girl be hold up a yellow water hose and water be pour out and a big brown dog be drink the water .',
#   'A young girl hold a run water hose , from which a brown dog next to her be drink .',
#   'A dog be drink the water be squirt from a hose by a little girl .',
#   'A little girl be hold a yellow hose for a brown dog .'],
#  '2951092164_4940b9a517.jpg': ['A boy and girl in swimwear and arm floater',
#   'a little boy and a little girl wear water wings be run on a path beside a black fence ,',
#   'A little boy and girl in their swimsuit wear arm float .',
#   'The boy and girl be play with arm float on .',
#   'Young boy and girl run with water wings on'],
#  '2273038287_3004a72a34.jpg': ['A black dog be run very fast on a light brown ground .',
#   'A dog run outside .',
#   'Black dog run fast on a field',
#   'Black dog run very fast .',
#   'Black dog run with his tongue out .'],
#  '3710971182_cb01c97d15.jpg': ['Lacrosse player struggle for control of the ball .',
#   'Lone red team player break through two black team player , to hit the ball',
#   'Men play field hockey .',
#   'Men play some type of sport on the field with what look like hockey stick .',
#   'Three guy be go for the ball in a field hockey game .'],
#  '3544483327_830349e7bc.jpg': ['A man in all black be use a green bike to trick over a sign say , " Free Dinner " .',
#   "A man be jump on a green bicycle over a sign that say ' free dinner ' .",
#   'A man jump a sign on his bike .',
#   'A man on a bicycle be jump over a sign that say " free dinner " .',
#   'boy on bike jump over a sign'],
#  '3055716848_b253324afc.jpg': ['A kid do a trick on a skateboard .',
#   'A man jump off of his skateboard on the top of a cement ramp .',
#   'a skateboarder jump .',
#   'Person do a trick on a skateboard in a skate park while person watch .',
#   'A skateboarder prepare to wipeout .'],
#  '3287236038_8998e6b82f.jpg': ['A girl and guy hold sign and hug .',
#   'A man and a woman hug .',
#   'A man hold a sign and a blond woman be embrace outdoors .',
#   'A man in green hold a sign hugs a blond woman .',
# ...
#   'A man sit on a bench read a newspaper .'],
#  '3118425885_f0cc035032.jpg': ['A blond lady wear a tan jacket sample a seafood dish at a restaurant .',
#   'A blond woman be eat in a busy restaurant .',
#   'A blurry woman eat fish .',
#   'A woman eat a large fish in a restaurant .',
#   'A woman be eat fish at a restaurant .'],
#  '3265209567_b3b9c8e0fe.jpg': ['A brown and white dog walk behind a brown cow .',
#   'A dog be run past a farm animal nearby a fence dive tall and short grass .',
#   'A dog run along beside a cow in a grassy field .',
#   'Dog and cow in field .',
#   'A brown and white dog run through the green grass .'],
#  '3073535022_4af81f360c.jpg': ['A man perform a trick on a surfboard in the water .',
#   'A surfer in a yellow shirt ride a wave on a white surfboard',
#   'a surfer on a white surfboard wear a yellow shirt with one arm in the air .',
#   'a surfer ride a wave .',
#   'A woman in a yellow shirt be surf on a white surfboard .'],
#  '3612485097_b706d950ed.jpg': ['A black man lean over as a white man jump on his back backwards .',
#   'A man hold up another with his back .',
#   'A man in midair with his back touch that of another man hunch over',
#   'one man in a hat flip over another man back in the grass .',
#   'Two person play outdoors .'],
#  '3549464203_8ab9c6160b.jpg': ['A child step up on a playground toy as arm reach for her .',
#   'A girl climb the stairway of a playground as arm reach for her .',
#   'An adult be encourage a young girl to try a slide .',
#   'A small child be climb up playground equipment while hand reach toward her from behind bar .',
#   'A girl be at a park play on a jungle gym .'],
#  '3503471307_464a8f588c.jpg': ['A boy be do a jump stunt on a bicycle in a run down street .',
#   'A boy be in the air on his bike .',
#   'A boy perform a one-handed trick on his bicycle by a rundown building .',
#   'A young man be pull trick on his bike in front of a warehouse .',
#   'A boy do a jump his bike into the air .'],
#  '2504764590_cf017c2a6e.jpg': ['A man be stand at edge of a pond , with two dog and be throw a branch be water .',
#   'A man be throw a big stick into the water so his two dog and go fetch it .',
#   'A man be throw a log into a waterway while two dog watch .',
#   'a person in a green jacket throw a stick into the water for a black and white dog to fetch whilst a brown and white dog look on .',
#   "Someone be at the water 's edge with two dog ."],
#  '2699733386_c346c87ea6.jpg': ['A black and brown dog be run and splash in the water .',
#   'A black and brown dog walk in the shallow of a large body of water .',
#   'A black dog run through water .',
#   'A black dog wade through water .',
#   'A dog be run in the surf .'],
#  '2546667441_bbe87a6285.jpg': ['A black dog be walk along the grass sniff at the ground .',
#   'A black dog run in the grass .',
#   'A dog sniff the grass .',
#   'Black dog on grass , sniff the ground .',
#   'Black dog with tan marking wear a blue collar stand on green grass .'],
#  '1301140633_046e4e8010.jpg': ['a boy in a blue shirt with dirt on his face',
#   'A boy with a dirty face smile .',
#   'A child with a dirty face look at the camera and smile .',
#   'Blond child with dirty face hold yellow bottle with red cap , plant in background .',
#   'A boy have blond hair and a dirty face .'],
#  '458735196_176e7df6b3.jpg': ['A brown dog indoors , with a large pink toy .',
#   'A dog with a wrinkled face bite on a pink toy .',
#   'A wrinkled dog play with a pink chew toy',
#   'A dog be carry a pink ball in its mouth .',
#   'This be a strange sight , a dog deliver a cookie .'],
#  '3304712466_18cbdb85fe.jpg': ['Bicycle racer be cheer on by some person .',
#   'Bicycle road racer pass a group of cheer spectator .',
#   'Crowd cheer on cyclist as they complete a race to a finish .',
#   'People on bicycle ride through a group of onlooker .',
#   'Racer on bike ride past a crowd .'],
#  '2721656220_5f4cda8bc1.jpg': ['A lady hold a beverage .',
#   'An attractive brunette woman smile and hold a beverage in front of her .',
#   'A woman hold a drink and smile .',
#   'A woman hold a drink and smile .',
#   'This woman be wear a white t-shirt and hold a cup .'],
#  '1253275679_e955fb7304.jpg': ['A boy have his head down and be wear a shirt that say Adhd .',
#   'a young boy wear a clever black and white shirt with his head bow down',
#   'A boy be wear a black t-shirt with an Ad parody of the Ac logo .',
#   'Young boy wear an Ac t-shirt look down .',
#   'Young boy with a black " Adhd " t-shirt nod off'],
#  '3668984985_b60ceb2ae9.jpg': ['A family sit on a bench in front of a pool .',
#   'a few couple sit on beanches next to a pool',
#   'A girl wear boot stand next to a swim pool and four person seat on a bench .',
#   'A group of person talk next to a pool with tree in the background .',
#   'People sit on a bench by a pool .'],
#  '3241726740_6d256d61ec.jpg': ['A man smoke a cigarette talk to a lady who be sit on step .',
#   'Lady in black stand and smoke with another girl sit on the step .',
#   'A person in black smoke while a woman in brown sat on the step .',
#   'A woman in a black coat be smoke and a woman in a gray coat sit on stone step .',
#   'Two woman smoke on the step of a white building .'],
#  '310213587_778fe8fb5b.jpg': ['A group of person sit on bench at a city park .',
#   'A man drink a beverage and hold a plastic bag far away from the other person .',
#   'A man drink a soda be stand in front of a bench near a group of person sit',
#   'A man in black clothes and a blue hat be take a drink and hold a shop bag .',
#   'A man be stand next to a bench drink a soda while other person sit on a bench nearby .'],
#  '2974501005_346f74e5d8.jpg': ['A boy do a skateboard jump at a skateboard park .',
#   'A kid do a trick on his skateboard .',
#   'A young boy be perform trick with a skateboard at a skate park .',
#   'A young man ride a yellow and black skateboard at the top of a ramp .',
#   'Kid do skateboard trick with his leg split and board between them .'],
#  '3716277216_c04002be81.jpg': ['Three african american woman be dress in bright orange and brown dress and head scarf .',
#   'three African woman in traditional orange costume be gather in front of a yellow curtain .',
#   'Three woman be dress in African clothes , and two of them be put on makeup .',
#   'Three woman wear traditional apparel make final touch on their clothing .',
#   'Woman be put their robe and headdress on .'],
#  '3320209694_db579cb607.jpg': ['A man in a purple have climb a rocky wall with his hand .',
#   'A man with a purple hat be climb a rock .',
#   'A man with a purple hat and bandage hand climb a wall of rock',
#   'A young man in a purple snow cap be rock climb .',
#   'This young man be rock climb'],
#  '3368865171_597d51cdd5.jpg': ['A child ride a unicycle while a crowd watch .',
#   'A little girl ride on a bicycle during a parade .',
#   'A small girl ride a unicycle .',
#   'Girl in plaid shirt ride a unicycle .',
#   'Person in check shirt ride unicycle while crowd watch .'],
#  '124881487_36e668145d.jpg': ['A man on bicycle ride down a rocky hill .',
#   'A man ride his dirt bike down a rocky trail .',
#   'A person ride a bike down a rocky hill .',
#   'Blurry picture of mountain biker descend rocky trail .',
#   'A mountain biker in blue ride down a rocky path .'],
#  '2701603045_6cbdc4ce7c.jpg': ['A boy be wade through water .',
#   'A boy up to his knee in water .',
#   'a boy wear white short , walk through the water .',
#   'A young boy with white swim trunk walk out of the water .',
#   'A boy be wade through the blue ocean .'],
#  '2278766574_f71f1704a8.jpg': ["A youn woman on a man 's back walk down a cement path with another couple behind them hold hand .",
#   'People walk on a path outside .',
#   'Several person be walk down a trail .',
#   'A man be give a woman a piggyback ride through a park .',
#   'Two couple walk on a path adorn with tree , bush and grass .'],
#  '347543966_b2053ae78c.jpg': ['A group of man stand outside a glass and steel building .',
#   'Three man be look at a wall very intently in a city .',
#   'Three man stand in a glass area .',
#   'Three person in a glass structure .',
#   'Three person stand in an outdoor glass structure .'],
#  '1143882946_1898d2eeb9.jpg': ['A lady wear a helmet hold a bike .',
#   'A woman in a blue vest and a sky blue helmet stand with her bicycle in traffic .',
#   'A woman in a helmet ride her bike behind a car .',
#   'A woman with a helmet and a backpack walk next to her bike .',
#   'Woman with bike and helmet wait for traffic .'],
#  '2029280005_a19609c81a.jpg': ['a man in a black shirt be rollerblade past a bench in a city .',
#   'A man be inline skate in front of a wooden bench .',
#   'A man be wear Rollerblade stand on a paved area near a park bench .',
#   'A man on Rollerblade travel down a sidewalk .',
#   'A man wear a black shirt and brown pants skate on a concrete surface near a park bench .'],
#  '3231751379_10ebf7150c.jpg': ['A goalie be crouch in a defensive position in front of the goal .',
#   'A hockey player in blue and red guard the goal .',
#   'An ice hockey goalkeeper in a red and blue strip be on his knee in front of the goal .',
#   'An ice hockey player be bend down on the ice .',
#   'A hockey player kneel on the ice .'],
#  '3069216757_c419b3898e.jpg': ['A girl in a pink striped shirt be in front of an armoire .',
#   'A girl in a pink striped shirt pose for the camera .',
#   'A girl wear a pink striped shirt throw her arm into the air .',
#   'A young girl wear a pink and orange stripped shirt extend her arm forward and appear to be happy .',
#   'A girl wear a pink striped shirt be stand in a doorway with her arm outstretched .'],
#  '3234719720_5bb2fc5ffa.jpg': ['A dark haired bearded man in a white dress shirt and black sweater and a woman in a black and white dress in a small space .',
#   'A man and woman , both in black and white , be in an elevator .',
#   'A man with a large beard and a woman wear a white necklace smile .',
#   'A nicely dress woman and bearded man in a small room .',
#   'A smile man lean to his right stand behind a smile woman lean to her left .'],
#  '491964988_414b556228.jpg': ['A little girl run down a path in a Japanese garden .',
#   'A little girl skip down a path near an idyllic country pond .',
#   'A young girl hop on a path to avoid puddle , locate near a lake .',
#   'A young girl be jump on a gravel road near a pond .',
#   'A girl run near a pond .'],
#  '2474047296_fd9179d438.jpg': ['A man in a white shirt and dress pants sit just underneath a stone archway .',
#   'a man wear a white shirt and black pants sit on a staircase',
#   'An old man sit in an ancient brick archway .',
#   'An old man with a white shirt and black pants sit on a chair in the open of a stone tunnel .',
#   'Elderly man sit in a doorway .'],
#  '3546891929_f31a99cd0d.jpg': ['A man in a bicycle helmet be talk on a cellphone with other person behind him .',
#   'A man in a helmet hold a cellphone .',
#   'A man in a plaid shirt with a red and black bike helmet on his cellphone .',
#   'A man wear a red bicycle helmet talk on a cellphone with other person in the background .',
#   'A man with a bicycle helmet on be use a cellphone in the midst of a crowd .'],
#  '2355763034_9fb61a8165.jpg': ['A flautist play a flute in a march band',
#   'A girl in a band be play a flute .',
#   'a girl in a red and black uniform be play a flute as part of a march band .',
#   'A woman in a red uniform be play a flute .',
#   'Girl in uniform play flute with march band .'],
#  '3065560742_f6e266ccd9.jpg': ['A boy play hockey lie on the ice , injure .',
#   'Two hockey player be down on the ice .',
#   'Two hockey player fall on the ice .',
#   'Two hockey player fall to the ground in a game .',
#   'Two hockey player slide into each other on the ice'],
#  '265528702_8653eab9fa.jpg': ['A man in sunglasses and a neatly trim beard overlook a woody valley .',
#   'a man pose with large grassy mountain off in the distance .',
#   'A man wear sunglasses stand before a forested landscape .',
#   'A man with a beard and sunglasses be stand in front of tree-covered hill .',
#   'Beard man with sunglasses in the mountain .'],
#  '2687539673_d54a8dc613.jpg': ['A girl and young boy be jump on a trampoline in a suburban yard .',
#   'A girl be jump on a trampoline with her arm in the air , while a boy in a blue shirt be bounce on his stomach .',
#   'A teenager girl jump high on a trampoline and a toddler fall on his stomach .',
#   'A toddler and a teenage girl jump on a trampoline .',
#   'Two child jump on a trampoline .'],
#  '3067500667_0fce8f28d4.jpg': ['A cricket batsman have be bowl out middle stump .',
#   'A cricket player swing his bat , but misses .',
#   'A man be stand in front of some red stick try to hit a ball .',
#   'A man be swing a paddle at a unique ball game .',
#   'A player hit the ball at a cricket game .'],
#  '2657484970_610e18144f.jpg': ['People be boat near a mountain .',
#   'Two person in a canoe are row past a large , tree-covered mountain .',
#   'Two person in a canoe float past a rocky , wooded cliff .',
#   'Two person in a canoe on a river beside a forested mountain .',
#   'Two person in a kayak are paddle past green foliage on a river .'],
#  '407008823_bdd7fc6ed5.jpg': ['A climber be make his way up a snowy mountainside .',
#   'a lone person jump through the air from one snowy mountain to another .',
#   'A man do trick in the snow .',
#   'A man dress in snow-gear take a leap into a snow-covered ravine .',
#   'People jump over a mountain crevasse on a rope .'],
#  '3675825945_96b2916959.jpg': ['A man in skateboard in an empty swim pool .',
#   'A man ride a skateboard up the side of an empty pool .',
#   'A skateboarder dress in white be drop into a blue bowl .',
#   'A skateboarder hang off the edge of a bowl at a skate park .',
#   'A skateboarder in an empty pool .'],
#  '1557838421_a33f2a4911.jpg': ['A gray and white dog be bite the ear of a white and brown dog .',
#   'Brown and white dog nip at a yellow dog .',
#   'There be two dog play with each other .',
#   'Two dog wrestle with each other with their teeth bare .',
#   'Two large dog attempt to bite each other playful .'],
#  '544301311_5e7d69a517.jpg': ['Woman sit outside on the step read and drink .',
#   'Two girl sit by a doorway on the step .',
#   'Two woman in period dress sit in a doorway .',
#   'Two woman in traditional European dress sit on a stoop , one drink , the other read .',
#   'Two woman with white head garb and long dress sit in front of a door on step read and drink a beverage .'],
#  '3624076529_9793655a21.jpg': ['a brown dog swim through a lake with a stick in his mouth .',
#   'A brown dog swim with a stick .',
#   'A dog hold a stick swim in the water .',
#   'A dog swim with a stick in its mouth .',
#   'A golden dog swim with a stick in its mouth'],
#  '537479916_c033897fac.jpg': ['A black dog finish run down a blue and orange ramp .',
#   'A black dog have just run down a blue and red ramp on an obstacle course .',
#   'A dog and person do an agility course .',
#   'a dog run dog a ramp .',
#   'A dog run down a ramp past its trainer .'],
#  '2737729252_b3fd9c05b1.jpg': ['A girl be take a picture of another girl in a park .',
#   'A girl be take a picture of another girl in a park .',
#   'A woman take a picture of another in purple in a park .',
#   'one girl take a picture of her friend',
#   'Two little girl play in a park lot .'],
#  '267162122_c3437414ec.jpg': ['a black puppy jump on the back of a white puppy',
#   'A black dog and a white dog wrestle .',
#   'A black dog and a white dog wrestle next to a food dish .',
#   'A black puppy stand over a white puppy .',
#   'A small black dog be stand over a small white dog lay on his side .'],
#  '2592711202_55f8c64495.jpg': ['A girl dress in blue enjoys a blue treat while put her white shoe back on .',
#   'A girl in a blue dress sit on the ground eat cotton candy .',
#   'A girl in a blue dress take off her shoe and eat blue cotton candy .',
#   'Child in blue dress hold sandal in one hand and eat blue cotton candy with other hand .',
#   'A girl in a blue dress be eat some blue cotton candy with one shoe off and one shoe on .'],
#  ...}

# %%
test_image_caption_mapping
# Out:
# {'3385593926_d3e9c21170.jpg': ['Dog be in the snow in front of a fence .',
#   'Dog play on the snow .',
#   'Two brown dog playful fight in the snow .',
#   'Two brown dog wrestle in the snow .',
#   'Two dog play in the snow .'],
#  '2677656448_6b7e7702af.jpg': ['a brown and white dog swim towards some in a pool',
#   'A dog in a swim pool swim toward sombody we cannot see .',
#   'A dog swim in a pool near a person .',
#   'Small dog be paddle through the water in a pool .',
#   'A small brown and white dog be in a pool .'],
#  '311146855_0b65fdb169.jpg': ['A man and a woman in festive costume dance .',
#   'A man and a woman with feather on her head dance .',
#   'A man and a woman wear decorative costume and dance in a crowd of onlooker .',
#   'one performer wear a feathered headdress dance with another performer in street',
#   'Two person be dance with drum on the right and a crowd behind them .'],
#  '1258913059_07c613f7ff.jpg': ['A couple of person sit outdoors at a table with an umbrella and talk .',
#   'Three person be sit at an outside picnic bench with an umbrella .',
#   'Three person sit at an outdoor cafe .',
#   'Three person sit at an outdoor table in front of a building paint like the Union Jack .',
#   'Three person sit at a picnic table outside of a building paint like a union jack .'],
#  '241347760_d44c8d3a01.jpg': ['A man be wear a Sooner red football shirt and helmet .',
#   'A Oklahoma Sooner football player wear his jersey number 28 .',
#   'A Sooner football player weas the number 28 and black armband .',
#   'Guy in red and white football uniform',
#   'The American footballer be wear a red and white strip .'],
#  '2654514044_a70a6e2c21.jpg': ['A brown dog run',
#   'A brown dog run over grass .',
#   'A brown dog with its front paw off the ground on a grassy surface near red and purple flower .',
#   'A dog run across a grassy lawn near some flower .',
#   'A yellow dog be play in a grassy area near flower .'],
#  '2339106348_2df90aa6a9.jpg': ['A girl with dark brown hair and eye in a blue scarf be stand next to a girl in a fur edge coat .',
#   'an Asian boy and an Asian girl be smile in a crowd of person .',
#   'Girl be in a crowd .',
#   'Two dark haired girl be in a crowd .',
#   'Two girl be look past each other in different direction while stand in a crowd .'],
#  '256085101_2c2617c5d0.jpg': ['A dog with its mouth open .',
#   'Brown and white dog yawn .',
#   'Closeup of dog in profile with mouth open .',
#   'Dog yawn',
#   "A dog 's mouth be open like he be yawn ."],
#  '280706862_14c30d734a.jpg': ['A black dog emerge from the water onto the sand , hold a white object in its mouth .',
#   'A black dog emerge from the water with a white ball in its mouth .',
#   'A black dog on a beach carry a ball in its mouth .',
#   'a black dog walk out of the water with a white ball in his mouth .',
#   'Black dog jump out of the water with something in its mouth .'],
#  '3072172967_630e9c69d0.jpg': ['A player from white and green highschool team dribble down court defend by a player from the other team .',
#   'Four basketball player in action .',
#   'Four man play basketball , two from each team .',
#   'Two boy in green and white uniform play basketball with two boy in blue and white uniform .',
#   'Young man play basketball in a competition .'],
#  '3482062809_3b694322c4.jpg': ['A group of tourist stand around as a lady put her hand near the mouth of a statue .',
#   'A woman be make a statue pretend to kiss her hand beside four boy at a bench .',
#   'A woman pose with a statue alongside a group of boy',
#   'A woman with a backpack lean again a statue while a group of boy sit on a bench talk .',
#   'Woman get her hand kiss by live statue street artist .'],
#  '1167669558_87a8a467d6.jpg': ['A man in yellow grimace .',
#   'a man wear a yellow shirt with a dramatic look on his face',
#   'A man in a yellow t-shirt be pull a large grin on his face .',
#   'There be a man , wear a yellow shirt , and grimace .',
#   'This man be smile very big at the camera .'],
#  '2847615962_c330bded6e.jpg': ['A dog lay on a mattress on a porch .',
#   'A dog roll on a mattress place on a porch and scratches his back .',
#   'A spotted dog roll over on a pad place on a porch .',
#   'A white dog roll on its back on a porch .',
#   'A spot dog roll on its back .'],
#  '3344233740_c010378da7.jpg': ['A man be stand on a sidewalk in the background with a blurry image of another man in the foreground .',
#   'A man stand at a busy bus stop .',
#   'a man stand next to a bus .',
#   'People in a city .',
#   'People walk down a street and past an open bus .'],
#  '2435685480_a79d42e564.jpg': ['A girl wear a brown cap , red sneaker , and a dark green coat sit on a rock bench .',
#   'A hiker in a jacket and knit cap sit with a backpack on atop a stone with a cloudy sky in the background .',
#   'A woman in a knit cap and green coat its on a stone block , look out .',
#   'A woman with her backpack sit on a large rock and look down over the mountain .',
#   'A lady be sit on a rock .'],
#  '3110649716_c17e14670e.jpg': ['A man help another man tie a red ribbon onto his arm .',
#   "A man help tie a red ribbon around another man 's right arm during a street parade .",
#   'A man be tie a red arm band around another man arm in a street .',
#   'One man help another attach a red ribbon to his forearm in the midst of a large group of person .',
#   'Two man stand together ; one be put something red on his arm .'],
#  '2511019188_ca71775f2d.jpg': ['A dog with a Frisbee in front of a brown dog .',
#   'A large black dog be catch a Frisbee while a large brown dog follow shortly after .',
#   'Two dark colored dog romp in the grass with a blue Frisbee .',
#   'Two dog be catch blue Frisbee in grass .',
#   'Two dog be play ; one be catch a Frisbee .'],
#  '2521770311_3086ca90de.jpg': ['A boy hold a picture over his head .',
#   'A boy in a long sleeve shirt be hold a box above his head .',
#   'A boy be inside hold something on top of his head .',
#   'A little boy hold a decorated cardboard box on his head .',
#   'a young boy with a samll cardboard box atop his head .'],
#  '2723477522_d89f5ac62b.jpg': ['A big dog chase a little dog on the grass .',
#   'A black dog be chase a small brown dog over grass .',
#   'A large brown dog be chase after a little brown dog .',
#   'Two brown dog run through the grass together .',
#   'two dog play in the grass .'],
#  '2218609886_892dcd6915.jpg': ['A man be sit on the floor outside a door and his head on his chin .',
#   'A man sit against a yellow wall wear all black .',
#   'A man wear a dark blue hat sit on the ground and lean against a building .',
#   'Man with black hat , coat , and pants sit next to the door of a building .',
#   'A man in a black hat be sit on the floor beside the green door .'],
#  '3745451546_fc8ec70cbd.jpg': ['A hiker ascend a snowy hill .',
#   'A man reach the top of a tall sand dune .',
#   'A person be hike to the top of a hill .',
#   'A person walk up a white sandy hill against the blue sky .',
#   'A person be wear short and climb a gray sand hill under a blue sky .'],
#  '2844018783_524b08e5aa.jpg': ['Three boy in a building under construction .',
#   'Three boy play in an unfinished building .',
#   'Three boy play in an unfinished space .',
#   'Three little boy be play on the floor of an unfinished house .',
#   'Two young boy sit and one young boy stand on an unfinished wooden floor .'],
#  '3100251515_c68027cc22.jpg': ['A crowd of person wear jacket and hold sign .',
#   'A group of protester picket in a road .',
#   'A large " green " peaceful protest be take to street .',
#   'A protest march be pass by a white stone building .',
#   'Group of person walk with poster .'],
#  '2207244634_1db1a1890b.jpg': ['A man wear a red helmet jump up while ride a skateboard .',
#   'A young man wear a red jacket perform a jump on a red skateboard .',
#   'A helmeted boy be do a stunt on a skateboard .',
#   'A young man be skateboard at a skate park .',
#   'Young man be perform a trick on a skateboard in a park .'],
#  '2943023421_e297f05e11.jpg': ['A black Mitsubishi be drive through a muddy puddle and spray water .',
#   'A blue car splash mud on a dirt road while drive through a puddle .',
#   'A blueish green car on a dirt road splash water on the left .',
#   'A dark blue car go through a muddy road and sprinkle some to the side .',
#   'There be a blue car on a road in road splash through a puddle .'],
#  '3286822339_5535af6b93.jpg': ['A busy city street with many person walk along it .',
#   'A couple walk to the side of a crowded walkway .',
#   'Chinese market street in a winter time .',
#   'People walk down a paved street that have red lantern hang from building .',
#   'People walk down street line with Chinese lantern .'],
#  '2479652566_8f9fac8af5.jpg': ['A little girl be sit on a counter dangle one foot in a sink whilst hold a dish jet washer .',
#   'A little girl play with a faucet .',
#   'A little girl wear sunglasses put her feet into a kitchen sink .',
#   'A young , barefoot girl in red sunglasses play in a sink .',
#   'A young girl wear red sunglasses sit near a sink and hold a faucet .'],
#  '1394368714_3bc7c19969.jpg': ['A dog wait as his owner rummage through a collection of stuff .',
#   'A man hold the leash of a pug bend down to look in a bin at an outdoor rummage sale .',
#   'A man with a pug dog bend over to pick something off a sidewalk .',
#   'A man with a pug on a leash bend down to examine merchandise .',
#   'A person hold a small dog on a leash be bend over and look through item .'],
#  '872622575_ba1d3632cc.jpg': ['A man climb a mountain .',
#   'A man climb a mountain .',
#   'A man be climb the side of a mountain .',
#   'A shirtless man climb up a steep mountain .',
#   'A young white man be climb a mountain with a rope as a guide .'],
#  '2309860995_c2e2a0feeb.jpg': ['a woman in a black overcoat and red hair with man in white walk behind her',
#   'A woman wear a black coat and sunglasses be stand in front of a man walk away with a backpack .',
#   'A woman wear sunglasses and a black coat as she walk .',
#   'There be a woman in a black jacket and sunglasses and a man in a white shirt with his back turn .',
#   'A woman in a dark coat be face the camera , while a man in a blue shirt face away .'],
#  '241347204_007d83e252.jpg': ['A football player in red and white be hold both hand up .',
#   'Football player gather around the referee .',
#   'Football player gathering to contest something to collaborate official .',
#   'Oklahoma University football player in front of a crowd of Sooner fan and next to three referee .',
#   'The red and white football team be talk with the official .'],
#  '3502343542_f9b46688e5.jpg': ['a woman wear a white helmeted look up as she be calm a huge rock wall',
#   'A woman be climb up a steep mountain over water .',
#   'People mountain climb .',
#   'People rock crawl up a steep obstacle .',
#   'These helmeted person be rock climb outdoors .'],
#  '757332692_6866ae545c.jpg': ['A smile woman punch a dog .',
#   'A tan dog lick a girl hand while lay down .',
#   'A woman dress in green be play with her tan dog .',
#   'A girl with a green scarf and a white dog appear to be play .',
#   'A light brown dog with white spot be nibble on the girl hand .'],
#  '2748729903_3c7c920c4d.jpg': ['a man crash into the water with his parachute .',
#   'A parasailer splash along the surface of a lake .',
#   'A person hang from a parachute make a splash as their body hit the water .',
#   'A person in a parachute slide across the water .',
#   'A parasailer be skip across the water .'],
#  '494792770_2c5f767ac0.jpg': ['A brown dog walk in the under brush .',
#   'A dog pause in bush .',
#   'a dog run through the long grass .',
#   'Brown dog with mouth open stand amidst greenery .',
#   'brown longhaired dog in garden .'],
#  '3213992947_3f3f967a9f.jpg': ['A girl in a red jacket , surround by person .',
#   'A woman in a puffy red jacket pose for a picture at an ice skate rink .',
#   'A woman in a red coat be smile , while person in the background be walk around in winter clothing .',
#   'A woman wear a red coat smile down at the camera .',
#   'A woman in a red jacket be smile at the camera .'],
#  '2295750198_6d152d7ceb.jpg': ['A girl be stand on one leg in the middle of the field .',
#   'A girl with her leg out on a lawn .',
#   'a little girl kick into the air .',
#   'A warmly dress girl kick up her leg outdoors .',
#   'Person walk in the field .'],
#  '2358898017_24496b80e8.jpg': ['A brown and white dog lay down in a grassy field .',
#   'A dog be crouch on the grass near a hurdle .',
#   'A dog race along a grassy track .',
#   'A tan and white dog be compete in an agility test .',
#   'Brown and white dog play in the grass .'],
#  '3222055946_45f7293bb2.jpg': ['A basketball player wear a black and white uniform dribble the ball .',
#   "At a woman 's basketball game , a white skinned woman dribble against the Chicago defense .",
#   'Basketball player in action .',
#   'A basketball player in white be dribble the ball towards a player in black .',
#   'Woman in white dribble basketball .'],
#  '444481722_690d0cadcf.jpg': ['A dark skinned man walk by a woman talk on a cellphone .',
#   'A male walk and a female talk on the phone beside a concrete building .',
#   'People stand outside near a concrete wall and a window .',
#   'Two person stand on a sidewalk .',
#   'Two woman , one carry a purse and paper , be stand on a sidewalk .'],
#  '2647049174_0fb47cee2e.jpg': ['A child put dirt into his mouth .',
#   'A little boy who be play outdoors be taste dirt .',
#   'A small child squat and put dirt into his mouth .',
#   'A toddler eat dirt .',
#   'A little boy wear a blue shirt be put dirt in his mouth .'],
#  '1174629344_a2e1a2bdbf.jpg': ['A crowd of person walk down a busy sidewalk .',
#   'A group of different person be walk in all different direction in a city .',
#   'A group of person walk a city street in warm weather .',
#   'Busy intersection in a summer time in a city',
#   'People in summer clothes be walk on the sidewalk of a large city .'],
#  '2921094201_2ed70a7963.jpg': ['A man sit in an airplane seat hold a young girl in his arm , surround by other passenger .',
#   "A small girl wear pink sleep on a man 's lap as they ride in an airplane .",
#   "A young girl fall asleep in her father 's arm while seat on an airplane .",
#   'Little girl sleep in crowded airplane',
#   'Young girl wear a pink sweater sit on a man .'],
#  '2553550034_5901aa9d6c.jpg': ['A boy climb a rocky area .',
#   'A boy climb rock in the wood .',
#   'A boy climb up some rock .',
#   'A young boy wear a white hat be climb rock .',
#   'A boy be wear a hat .'],
#  '3045613316_4e88862836.jpg': ['Three man look into the distance',
#   'Three man be stand on a cliff overlook mountain and the ocean .',
#   'Three man be stare at the big , green hill in the distance .',
#   'Three man look at grass cover hill .',
#   'Three man stand on a mountain look at another .'],
#  '2706766641_a9df81969d.jpg': ['A child and floor cover in white powder .',
#   'A little boy be in the corner cover in a white powder that be all over him and the floor .',
#   'A little boy with a mess all over his face and feet stand next to a door .',
#   'A young boy be catch make a mess of his room .',
#   'A young child cover with white powder .'],
#  '510531976_90bbee22a2.jpg': ['A boy in a white tracksuit be break dance on the ground in front of a colorful wall .',
#   'A city break dancer start to spin .',
#   'A man balance on his forearm while a child watch in front of a colorful background .',
#   'child watch a man do dance move .',
#   'A break dancer be wear a white shirt and gray pants .'],
#  '485245061_5a5de43e20.jpg': ['A man crouch on a snowy peak .',
#   'A man in a green jacket stand in deep snow at the base of a mountain .',
#   'A man kneel in the snow .',
#   'A man measure the depth of snow .',
#   'A mountain hiker be dig steak into the thck snow .'],
#  '3070011270_390e597783.jpg': ['A black and brown dog be walk in the water and look at the camera .',
#   'A black dog with brown on his face be swim .',
#   'a brown and black dog swim in a river',
#   'A large dog look up as he swim .',
#   'Dog with black and tan face stand in water look up at camera .'],
#  '1352410176_af6b139734.jpg': ['A blond girl be step on vertical log in the sand .',
#   'A little girl be walk along a line of log on a sandy beach .',
#   'A young girl balance on wooden pylon at a beach .',
#   'A young girl be walk on stump on a beach next to the ocean .',
#   'Girl walk along the top of wooden post set into sand on a beach .'],
#  '1131932671_c8d17751b3.jpg': ['A boy be jump on a bed .',
#   'A boy jump up from a green bed .',
#   'A boy jump from one bed to another .',
#   'A small child be jump on a bed .',
#   'A boy in blue short be bounce on a bed .'],
#  '3155451946_c0862c70cb.jpg': ['Several basketball player be grab for the ball during a game .',
#   'A basketball player in white hold the ball .',
#   'Three basketball player leap to grab a ball .',
#   'three man be play a game of basketball',
#   'Three man be play basketball .'],
#  '2762301555_48a0d0aa24.jpg': ['A girl be cold after come out of a pool and be cover by a towel .',
#   'A little girl be cover in a towel at a swim pool .',
#   'a toddler be with wet hair stand by swim pool wrap in a towel .',
#   'A wet child be shiver in a towel in front of a pool .',
#   'A wet child shiver under a towel at a pool .'],
#  '3442242092_e579538d82.jpg': ['A couple be walk down a sidewalk .',
#   'A couple walk down a city street hold hand .',
#   'An Asian girl wear a pink and black striped top be walk next to a girl in the gray top .',
#   'Two student walk down a street , hold hand .',
#   'Two woman be walk casually down a street together .'],
#  '2415803492_56a673dc25.jpg': ['A man and a girl stand in front of a large crowd .',
#   'A man dance with a girl .',
#   'A man in a suit dance with a young girl in front of an audience .',
#   'A man wear black dance with a young girl wear a pink shirt .',
#   'A man wear a blue brother suit be dance with a little girl in the pink top .'],
#  '2884301336_dc8e974431.jpg': ['A dog come out of a blue baby pool with a ball in his mouth .',
#   'A dog be in a paddle pool play with a ball .',
#   'A dog play with a ball in a kiddie pool .',
#   'A dog splash in a small pool with a small football .',
#   'White and black dog play in a blue pool with a ball .'],
#  '3453259666_9ecaa8bb4b.jpg': ['two child be play on a swing make out of a tire .',
#   'Two child swing around in a tire swing at a park .',
#   'Two child swing on a tire swing .',
#   'two small child happy play on a tire swing .',
#   'Two small child wear blue jean enjoy swing in a tire swing .'],
#  '3016606751_0e8be20abd.jpg': ['A man leap into the air with a mountain vista behind him .',
#   'A man pose as he jump from rock to rock in a forest .',
#   'A man step off of a boulder .',
#   'A young man leap through the air from a rocky mountaintop .',
#   'A young man pose as he jump in midair between two rock in a highland .'],
#  '3642220260_3aa8a52670.jpg': ['A black dog on a rocky beach .',
#   'A black dog walk along an ocean front .',
#   'A black dog walk on a beach near rock .',
#   'a black dog walk on the sand .',
#   'Black dog walk on a beach after swim in the ocean .'],
#  '2612488996_9450de0e54.jpg': ['A homeless man in a white cap be stand behind large , orange cone .',
#   'A homeless man stand in a construction site .',
#   'A homeless man stand with a sign next to orange construction cone .',
#   'A man hold a sign read " Homeless Anything Help " near a construction site .',
#   'Stacks of orange safety cone in front of a man hold up a homeless sign .'],
#  '1499581619_a5f65a882c.jpg': ['A couple dress in hoodies kiss on a beach .',
#   'A man and a woman share a kiss on a beach .',
#   'A man with a brown hooded jacket be kiss a girl with sunglasses .',
#   'There be a couple kiss on a beach .',
#   'Two person kiss on a beach .'],
#  '1427391496_ea512cbe7f.jpg': ['A child in a black shirt stand on a wooden dock near a picnic table .',
#   'A little boy be smile for the camera on a playground',
#   'A young boy hold onto a blue handle on a pier .',
#   'A young child stand on a wood dock next to the water .',
#   'Boy in green sweater with white stripe on sleeve stand on wood plank floor with body of water in the background .'],
#  '3601843201_4809e66909.jpg': ['A man race on a motorbike',
#   'A motorcycle rider drive fast around a curve on a track .',
#   'A person wear a red and white uniform be race a motorcycle with the number 58 on it .',
#   'A red and white motorcycle be be ride around a bend on a racetrack .',
#   'Red and white motorbike number 58 race around a track .'],
#  '3584561689_b6eb24dd70.jpg': ['A group of boy play basketball together .',
#   'Basketball player make a shot as other player to try to intercept .',
#   'Some teenager be scramble for a basketball underneath a net .',
#   'These person be play basketball outdoors .',
#   'two man play basketball under a blue sky'],
#  '138718600_f430ebca17.jpg': ['Two bicycle be stand behind two person sit on the grass near a body of water .',
#   'Two blond woman sit beside their bicycle in the grass beside a body of water .',
#   'Two girl be sit on a path by a river with their bicycle park beside them .',
#   'Two person be sit by a pond , next to their bike .',
#   'Two woman sit in the grass with their bike behind them .'],
#  '3220126881_b0a4f7cccb.jpg': ['Three person stand by a doorway pose for a photograph .',
#   'Two man and a woman pose for a picture .',
#   'Two man and a woman smile at the camera .',
#   'Two man and a woman stand near a doorway .',
#   'Two man and a woman with their arm around each other .'],
#  '300314926_0b2e4b64f5.jpg': ['A man get lot of air time as he wakeboards .',
#   'A man be waterski on one ski and jump out of the water .',
#   'A wakeboarder leap in the air .',
#   'A waterskier be jump through an air whilst hold onto the line .',
#   'A man on a board use a wave to jump high into the air .'],
#  '3128164023_ebe8da4c32.jpg': ['Dog chase each other .',
#   'Two brown and white dog wrestle while run across the wet sand .',
#   'Two dog , identical white with brown spot wrestle on jet black sand .',
#   'Two white and brown dog play on a beach .',
#   'Two white dog with brown marking play .'],
#  '324208502_674488bcea.jpg': ['An old man be sit on a red bench with a young man .',
#   "An old person be sit on a red bench next to a black man with a child 's bookstore behind them both .",
#   'A person sit on a red bench to eat while another watch .',
#   'two man sit on a bench .',
#   'Two person sit on a red bench in front of book .'],
#  '3647750811_395fbd397e.jpg': ['a black and white dog be wear a red collar whilst walk on the grass .',
#   'A dog be run awkwardly .',
#   'A multicolor dog in a red collar crouch on the grass .',
#   'Black , brown and white dog crouches on three leg in the grass .',
#   'A dog with the red collar be white , black , and brown .'],
#  '3458211052_bb73084398.jpg': ['A crowd watch a dirt bike race',
#   'A group of person on the sideline of an Atv race .',
#   'A line of person stare at vehicle on the dirt track',
#   'A line of spectator at a race .',
#   'People stand at fence watch motor vehicle in field'],
#  '2414397449_2ac3b78e0d.jpg': ["A little white and black dog be leap over a big brown dog 's head in a field of green grass .",
#   'A small dog land on a big dog try to get a disc .',
#   'A small white dog leap over the back of a large dog to chase his toy .',
#   'Two dog be play in a field of tall grass .',
#   'White and black dog jump over red haired dog in grass .'],
#  '3085226474_62aba51179.jpg': ['A group of woman be perform onstage .',
#   'People in a dance',
#   'Some woman in white perform on a stage .',
#   'Woman participate in a skit onstage .',
#   'Woman who look alike be perform on a stage .'],
#  '968081289_cdba83ce2e.jpg': ['A boy jump off of a dock while his friend watch',
#   'Two boy be climb a wooden platform and jump into a river .',
#   'Two boy jump off a pier into the water .',
#   'Two boy prepare to jump off a pier locate on a large body of water .',
#   'Two child jump off a dock into a lake .'],
#  '2436081047_bca044c1d3.jpg': ['A girl dismount from a swing as high as she can and land on rubber tile below .',
#   'A girl in a pink shirt jump out of a move swing .',
#   'A little girl wear a pink shirt jump off a swing .',
#   'A young girl jump off a playground swing .',
#   'A young girl in the pink shirt and blue jean be jump off a tire swing .'],
#  '2813992915_f732cf8539.jpg': ['A man be do trick on a bicycle on ramp in front of a crowd .',
#   'A man on a bike execute a jump as part of a competition while a crowd watch .',
#   'A man ride a yellow bike over a ramp while others watch .',
#   'Bike rider jump obstacle .',
#   'Bmx biker Jump off of ramp'],
#  '3627011534_485f667b10.jpg': ['A child with a pink headband and blue shirt smile .',
#   'A girl in a purple shirt and pink headband pose',
#   'A young girl be wear a purple shirt and pink headband .',
#   'A young girl with a purple shirt and a pink hair band stand near the wood .',
#   'Smile young girl wear pink headband and lavender shirt'],
#  '3214237686_6566b8b52f.jpg': ['a lone snowboarder jump in the air do a trick .',
#   'A man in black be take a jump on a snowboard .',
#   'A person ride a snowboard jump high over a snowy hill .',
#   'A person with a yellow and black striped snowboard jump on a snowy hill .',
#   'a snowboarder jump off a snow jump .'],
#  '1248940539_46d33ed487.jpg': ['Three child be play in sand near to a beach .',
#   'Three child play in sand at beach',
#   'Three girl play in the sand .',
#   'Three little blond girl , two in blue , one in pink , play on a sunny beach .',
#   'Three young girl dance on a beach in the sand .'],
#  '2064790732_219e52e19c.jpg': ['A boy without a shirt be run in a street while several person stand behind him .',
#   'A little boy dance with a group of person behind him on a city street .',
#   'A small boy dance on the concrete surround by adult .',
#   'A little boy wear no shirt be run by a crowd of person .',
#   'A shirtless little boy be walk around adult .'],
#  '544576742_283b65fa0d.jpg': ['A rock climber repel off a rocky wall .',
#   'A woman climb a rock cliff .',
#   'A woman in jean rock climb .',
#   'A woman be hold onto a huge rock and have red string around her .',
#   'Woman go rock climb .'],
#  '2731171552_4a808c7d5a.jpg': ['A boy hold by a man point his arm towards the sky , as another boy peer through his hand into the air .',
#   'A boy in a blue and white shirt be point up and a second boy in a white shirt shield his eye .',
#   'a man hold a young boy on his shoulder .',
#   'One child be point to the sky and another be try to block the sun to look',
#   'One man look into the distance next to another who have his hand in the air .'],
#  '3609032038_005c789f64.jpg': ['a dirt bike rider ride across a rock .',
#   'A dirt bike rider take an unconventional trail in a rocky area .',
#   'A motocross bike be be ride over rock .',
#   'A motorcycle rider on a path of rock with a person hold a camera in the background with tree all around .',
#   'A rider on motorcycle , ride over rock .'],
#  '3119875880_22f9129a1c.jpg': ['A boy climb rock .',
#   'A boy crawl through a rock tunnel with his brother and father behind him .',
#   'A man watch two small boy play in a naturally form rock .',
#   'child play on rock .',
#   'Kid play in a rocky area .'],
#  '3339140382_2e49bc324a.jpg': ['A three person sky dive team in the air perform a stunt .',
#   'Three person , wear parachute , be free-falling together through the sky .',
#   'Three skydiver be in formation above the cloud .',
#   'Trio of skydiver hold hand in sky .',
#   'Two person be parachute over white cloud .'],
#  '2712787899_d85048eb6a.jpg': ['A blond woman in black jean be sit on a wall examine her nail .',
#   'A woman in black jean sit on the railing of a bridge with a harbor in the background .',
#   'A young woman sit on a ledge with a black purse look at her finger nail .',
#   'girl sit on wall look at her nail',
#   'A girl have a black purse and be sit on the side of a ledge .'],
#  '3655155990_b0e201dd3c.jpg': ['Two dog play in the water .',
#   'Two dog play in the water , one be bound at the other .',
#   'Two furry beige dog play in ocean surf .',
#   'Two white dog be splash around in white wave .',
#   'Two white , longhaired dog play in the ocean'],
#  '3325497914_f9014d615b.jpg': ['an old asian lady hold the hand of a little asian girl .',
#   "Asian woman hold little girl 's hand in park-like area , point off-camera .",
#   'A woman hold a little girl hand be point to something try to show her .',
#   'A woman hold the hand of a small girl and point towards bush .',
#   'A woman be hold the girl hand near a bush .'],
#  '468310111_d9396abcbd.jpg': ['A black and white dog be run through a cow field .',
#   'A black and white dog run in the grass where there be some cow .',
#   'A calf be run in field while cow look on .',
#   'A cow herd graze in a pasture with a dog run in the foreground .',
#   'A dog run in the grass around sheep .'],
#  '747921928_48eb02aab2.jpg': ['a boy hold two sparkler .',
#   'A boy play with sparkler at night .',
#   'A child hold sparkler in the dark .',
#   'A little boy hold fire sprinkler out in front of him .',
#   'A small boy hold two firework sparkler .'],
#  '3639967449_137f48b43d.jpg': ['Two boy be sit in front of a structure eat Popsicle .',
#   'Two boy eat popscicles outside .',
#   'Two boy sit and eat ice cream .',
#   'Two little boy be sit on a step eat ice lollipop .',
#   'Two young boy eat red and blue popcycles .'],
#  '2374652725_32f90fa15c.jpg': ['A big white dog and a small black dog sit in the snow .',
#   'A large white dog watch a little black dog run in the snow .',
#   'A small dog and a large dog in the snow .',
#   'A tall white dog sit and watch a small black dog run around him in the snow .',
#   'A white dog look at a black puppy in the snow .'],
#  '3363750526_efcedc47a9.jpg': ['A black and white dog be run on a beach .',
#   'A dog run on a beach .',
#   'Black and white dog on wet sand .',
#   'A black and white dog be run in the damp sand .',
#   'This large black and white dog be run on the sand .'],
#  '2689001252_e0016c89f0.jpg': ['little girl in swimsuit be laugh',
#   'A girl in a yellow bathe suit laugh and point at a girl in an orange suit while another girl look on .',
#   'Girl in bathe suit point and laugh at child in orange bathe bottom while another girl look on',
#   'A girl in yellow be laugh at a girl wear orange whilst be watch by a girl in blue .',
#   'Three child in swimsuites be have fun outside near a white building .'],
#  '3154641421_d1b9b8c24c.jpg': ['A basketball player prepare to shoot the ball',
#   'A basketball player take a shot .',
#   'A black man play basketball with orange shoe',
#   'Basketball player with 32 on jersey jump to make a shot , crowd in background .',
#   'Miami basketball player shoot'],
#  '2631300484_be8621d17b.jpg': ['A blond boy stand among person in a shady set with a large snake wrap around his chest .',
#   'A boy carry a huge snake around his neck outside .',
#   'A boy have a large snake wrap around him .',
#   'A little boy in a green shirt be hold a large snake .',
#   'A young boy have a snake drape over his shoulder .'],
#  '3677318686_b018862bb7.jpg': ['A boy in a park play with two orange ball .',
#   'A boy in a purple shirt toss orange ball on a lawn .',
#   'A little boy in a purple shirt and blue short play with orange ball .',
#   'Boy play on the grass with an orange ball .',
#   'Little boy juggle orange ball in a park with a playground behind him .'],
#  '405615014_03be7ef618.jpg': ['A man in a lime green vest directs traffic',
#   'A policeman wear a green vest blow his whistle and move his arm .',
#   'A policeman wear a neon green vest have a whistle in his mouth while direct traffic .',
#   'A police officer in a yellow vest directs traffic .',
#   'A traffic director wear a yellow safety suit mark , " Seattle Police . "'],
#  '533979933_a95b03323b.jpg': ['a boy hold an oar walk through the ocean .',
#   'a boy be carry a paddle whilst walk through the water on a beach .',
#   'A boy be on a beach with a paddle in his hand as he walk through the ocean water .',
#   'A boy with an oar walk out of the surf and onto a beach .',
#   'A little boy walk with a paddle out into the sand .'],
#  '3437654963_c4fdc17e8b.jpg': ['A mama bear and its cub be growl directly at one another .',
#   'Bear be face each other with their mouth wide open .',
#   'Two bear be growl at each other .',
#   'Two bear bare their teeth at one another .',
#   'Two brown bear touch , face to face , with mouth open .'],
#  '3462454965_a481809cea.jpg': ['A group of dog run beside a pond through a field .',
#   'several multicolored dog run through the grass .',
#   'Three black dog , two with tan marking , be run along grass .',
#   'Three dog run through a field .',
#   'Three dog run on scrubby grass , a lake and picnic table nearby .'],
#  '2256133102_e2c8314ecb.jpg': ['A man in blue pants repel off a cliff over water .',
#   'A man be hang by a line off a cliff above water .',
#   'An individual rappel down a cliff towards the water',
#   'A person hang from a rope on a cliff',
#   'Someone dangles on a rope from a rocky cliff over the ocean .'],
#  '3186412658_2ab2ebd397.jpg': ['A group of woman hold each other up to catch a ball .',
#   "A woman 's sport squad perform some trick , include lift member high and toss a ball .",
#   'Team member be lift up high to catch a fly ball .',
#   'three young woman jump into the air to catch a ball .',
#   'Woman be lift by other woman play volleyball .'],
#  '3554634863_5f6f616639.jpg': ['A crowd of person be stand around a yellow-suited musician .',
#   'A man in yellow set up a band next to a crowd .',
#   'A musician and a crowd next to stage full of musical instrument .',
#   'Man in yellow-gold suit and hat lean forward with musical instrument to his right .',
#   'A man in a yellow suit stand near musical instrument and a crowd .'],
#  '3223055565_68973f5d20.jpg': ['A boy in a blue sweatshirt play Frisbee with two black dog .',
#   'A man stand in the snow and hold a toy up while a black dog jump for it .',
#   'a young person play in the snow with two black dog .',
#   'A man be play with two dog in the snow .',
#   'Two dog play with a human and a disc in the snow .'],
#  '1554713437_61b64527dd.jpg': ['A big hound dog walk on a log in the wood .',
#   'A brown dog walk on top of a fell tree trunk .',
#   'A gray dog walk on top of a fall tree in the wood .',
#   'A skinny brown dog walk across a large piece of fall tree .',
#   'A skinny brown dog be walk on a fall tree .'],
#  '3150742439_b8a352e1e0.jpg': ['A man in a black hoodie watch a man in a red cap .',
#   'A man stand on a street with a suitcase in front of him while another man bend down to look at what be display on top of it .',
#   'A man wear a red hat look down as another man watch .',
#   'Two man be stand on a street cover in graffiti .',
#   'Two person on a street , one person look down .'],
#  '2238019823_79318d1f11.jpg': ['A man surfs by the Golden Gate bridge on a foggy day .',
#   'A surfer ride a wave under a red bridge .',
#   'A surfer by a bridge in foggy conditions',
#   'A surfer under a bridge .',
#   'Man surf under the Golden Gate Bridge on a foggy day .'],
#  '3484832904_08619300d9.jpg': ['A child wear black and purple play baseball .',
#   'A girl close her eye as she swing a bat and miss a softball .',
#   'A girl play softball take a strike .',
#   'A girl play softball , take a swing .',
#   'A softball player swing at a softball and miss it .'],
#  '3365783912_e12c3510d8.jpg': ['Two elderly person walk down a city sidewalk by words write in chalk .',
#   'Two man walk along a busy city street with words print on a sidewalk .',
#   'Two man walk through a city with words on a street .',
#   'Two old man in business attire be walk in a city , text graffiti be visible on a sidewalk .',
#   'Two person walk down a city street that have writing on it .'],
#  '3185409663_95f6b958d8.jpg': ['A little boy run away from the approach wave of the ocean .',
#   'A little girl run across a wet beach .',
#   'A little girl run on the wet sand near the ocean .',
#   'A young girl run across a wet beach with the ocean in the background .',
#   'Child run on a beach .'],
#  '3207358897_bfa61fa3c6.jpg': ['An Asian girl perform a routine with two red flag in a square .',
#   'a person wave long red flag',
#   'A woman play with long red ribbon in an empty square .',
#   'Lady wave two long red streamer around',
#   'Two person work with long ribbon in a Chinese courtyard .'],
#  '3263497678_8bb688ca01.jpg': ['2 runner be ready for a track .',
#   'Two person be in run race start position with a long lane field ahead of them .',
#   'Two runner be at start block , ready for a race .',
#   'Two runner be at the start line get ready to race .',
#   'Two runner get ready to race on a track .'],
#  '1897025969_0c41688fa6.jpg': ['A black dog and a tan dog fight .',
#   'A black dog and a white dog be wrestle on the ground .',
#   'A black dog bite a white dog while stand on the sand .',
#   'two dog fight .',
#   'Two dog , one white and one black , play with each other in the sand .'],
#  '3657016761_d553e514d9.jpg': ['A child at a water park be spray from all side by a ring of water .',
#   'A child in a pink and black bathe suit walk through water mist from colored ring .',
#   'A young girl stand under three large ring that shoot water in a water park .',
#   'Colorful ring spray water at little girl wear swimsuit .',
#   'A little girl in her bathe suit stand near the sprinker and squeal .'],
#  '3537400880_8f410d747d.jpg': ['A girl do the split in the air while jump on a trampoline .',
#   'a young woman be jump on a trampoline',
#   'Girl in black and white top and black legging jump on trampoline .',
#   'A girl be jump on a trampoline , outdoors in a backyard .',
#   'Young woman jump on trampoline .'],
#  '2419221084_01a14176b4.jpg': ['A white dog run past another dog who be stand beside some patio furniture .',
#   'Two dog be outside near patio furniture .',
#   'two small brown and white dog stand beside some white chair',
#   'Two small dog play on a lawn .',
#   'Two small white dog play in the yard .'],
#  '172097782_f0844ec317.jpg': ['A man in swim trunk and a red life vest jet ski .',
#   'A man waterski with one hand .',
#   'A man wear a red life jacked be hold a purple rope while waterski .',
#   'A man wear swim trunk be waterski backwards use only one hand .',
#   'Person in red ski jacket ski backwards'],
#  '244571201_0339d8e8d1.jpg': ['A bunch of dog and kid play in a swim pool .',
#   'Dog and person play in a pool .',
#   'Five dog be swim and four person be wade , together inside a dog park pool .',
#   'People and several dog in a swim pool in a park like set .',
#   'Several person and dog be in or near a large outdoor swim pool .'],
#  '3467219837_7d62213dec.jpg': ['A dog with a muzzle be lead several other dog in a race',
#   'A greyhound leap in a race .',
#   'A muzzled dog in a race , with four dog follow .',
#   'Five dog be race .',
#   'Five dog be race on a dirt track .'],
#  '2928152792_b16c73434a.jpg': ['A boy in a green soccer outfit hang from a machine .',
#   'A boy in a green soccer uniform hang upside down from a farm vehicle .',
#   'A child hang from a hay bale loader .',
#   'A young boy be tilt over on a cart smile at the camera',
#   'A girl be hang off of a tractor equipment .'],
#  '401079494_562454c4d6.jpg': ['A black and gray dog',
#   'two black dog fight .',
#   'two black poodle fight .',
#   'Two black poodle playful tussle on a grassy , manicured lawn .',
#   'Two small black dog face each other with their mouth open .'],
#  '2396691909_6b8c2f7c44.jpg': ['A girl in a white dress walk next to a girl in a blue dress .',
#   'A woman in a white dress and a woman in a blue dress onstage .',
#   'A young girl with makeup and jewelry smile .',
#   'Blond girl in white top with star stand beside brunette woman in blue top with star .',
#   'Two teenage girl be wear fancy dress at an event .'],
#  '3243588540_b418ac7eda.jpg': ['A girl be get a tattoo on her hand .',
#   'A girl sit patiently as another one draw henna on her .',
#   'A girl be stand as the other girl with glasses work on her hand paint .',
#   "A woman in a white sweater be paint a tattoo on a teenager 's hand .",
#   'Two girl at a table with paper between them .'],
#  '3592992234_6d3fe58a70.jpg': ['A man in a white shirt swing a stick',
#   'A man in a white shirt walk in the tall grass hold a stick .',
#   'A man be walk in a field carry a stick .',
#   'A man with a stick in his left hand in a field',
#   'Man near golf course prepare to throw a stick'],
#  '1417031097_ab656bc4bd.jpg': ['A person be laugh on a roller coaster ride .',
#   'A photo of a ride at an amusement park on an overcast day .',
#   'People be in a ride that drop you from a great height .',
#   'People on an amusement park ride .',
#   'People on a ride at a fair .'],
#  '1122944218_8eb3607403.jpg': ['A baby in a white garment hold a flag with crescent moon and star .',
#   'A baby be hold a small black flag with a moon and a star on it .',
#   'A baby wear a white gown wave a Muslim flag .',
#   'A little toddler dress in white be smile while a lady help him wave a flag .',
#   'Baby in white outfit hold black and white flag .'],
#  '3149919755_f9272b10b3.jpg': ['A black dog be look at the ball on a beach by the ocean .',
#   'A dog and a ball on a beach .',
#   'A dog stand on a beach with a ball nearby .',
#   'A dog stand on a beach at sunset .',
#   'Dog in shadow on beach at sunset .'],
#  '2682382530_f9f8fd1e89.jpg': ['A man in black short be stretch out his leg .',
#   'A man practice a high kick on a cement near the grass .',
#   'A young , fit man wear short do a high right kick in the air .',
#   'A young man practice a martial art kick skill in front of his home in the early morning .',
#   'A young man wear short and no shirt be high kick as water fly from his clothing .'],
#  '2453971388_76616b6a82.jpg': ['Two girl run through pool while water spray over them',
#   'Two girl run through a sprinkler in a pool .',
#   'Two smile little girl play in a fountain with other person .',
#   'Two young girl be run through shallow water at a pool .',
#   'Two young girl run through a pool while water spray them .'],
#  '3079787482_0757e9d167.jpg': ['A little girl hug another little girl .',
#   'A young child be be hold by another child look straight at us .',
#   'Two toddler pose for the camera .',
#   'Two young child hold each other and pose .',
#   'Two young girl hug .'],
#  '2900274587_f2cbca4c58.jpg': ['A body of water at sunset .',
#   'A sunset over a lake .',
#   'A sunset sky over ripple water .',
#   'A water scene with a sunset in the background .',
#   'This be a beautiful sunset on the water .'],
#  '3301859683_2d5e4b40a3.jpg': ['A man ski down a hill .',
#   'A man ski down a snowy hill .',
#   'A person ski downhill .',
#   'a skier dress in black speed down a mountain .',
#   'Closeup of a skier with his pole out wide to the side .'],
#  '1287073593_f3d2a62455.jpg': ['A group of dog pull a person on a dog sled up a hill .',
#   'Dogsled rider pull past flag on snowy hill .',
#   'Dog pull a sled in a sled race .',
#   'Five sled dog be pull a person on a sled , through the snow .',
#   'A man be mush his dog on a snow trail'],
#  '2718495608_d8533e3ac5.jpg': ['a brunette girl wear sunglasses and a yellow shirt',
#   'A girl in sunglasses smile .',
#   'A girl wear a yellow shirt and sunglasses smile .',
#   'a girl wear sunglasses smile for the camera .',
#   'A woman with a yellow shirt wear sunglasses and smile .'],
#  '2054869561_ff723e9eab.jpg': ['A black and white dog chase a pink Frisbee .',
#   'A black and white dog be chase a ping Frisbee .',
#   'A black and white dog be look at a pink Frisbee on a court .',
#   'A black and white dog be run with a pink Frisbee next to him',
#   'A dog run to catch a Frisbee on Astroturf .'],
#  '3567061016_62768dcce1.jpg': ['A bird fly in the air',
#   'a bird fly low to the ground .',
#   'A bird with its wings spread',
#   'A hawk fly down towards the grass .',
#   'A hawk be fly , trail line from its leg .'],
#  '3221036999_3f7b152d8a.jpg': ['A man perform a skateboard jump off the top of a ramp .',
#   'A skateboarder become airborne at the top of a black and yellow ramp .',
#   'A skateboarder do a trick on a black and yellow striped ramp .',
#   'Skateboarder fly over ramp outside .',
#   'This man be do a stunt on a skateboard outdoors .'],
#  '2554081584_233bdf289a.jpg': ['a climber be between two large red rock .',
#   'A man squeezes between two rock formation .',
#   'a man wear a yellow shirt and white hardhat stand inside a crevice between two rock face .',
#   'A rock climber stand in a crevasse .',
#   'A rock climber appear to be stick between a rock and a hard place .'],
#  '3250695024_93e8ab7305.jpg': ['A group of person stand together and look at the camera .',
#   'A man , a woman , a girl , and a young girl look puzzle and concern .',
#   'A man , woman and one girl face the camera , while one girl face away .',
#   'Oriental man , and two woman face camera and young child with back to camera .',
#   'Three person look concerned face us , a girl in a backback face away .'],
#  '3630332976_fdba22c50b.jpg': ['Boy pull other boy over back .',
#   'One boy hoist another boy up on his back .',
#   'One child lift another on his back , inside a room .',
#   'A boy in a gray shirt be hold a boy in a red shirt on his back .',
#   'Two boy be back to back as one hold up the other .'],
#  '2902269566_419d9f1d8e.jpg': ['A dirt biker leap through the air .',
#   'A person on a motorcyle do a stunt in the air .',
#   'Man on a dirt bike',
#   'Motocross rider during jump wear black and white striped helmet',
#   'A red motocross bike and its rider be airborne above tree .'],
#  '2544182005_3aa1332bf9.jpg': ['A little boy with a blue shirt be wear a helmet and ride a two wheeled bike .',
#   'a young boy ride a purple bike .',
#   'A young child be ride a purple bike .',
#   'A young child ride a small purple bike while wear a red helmet .',
#   'A young child wear a bike helmet ride a two wheel bike .'],
#  '2999730677_0cfa1c146e.jpg': ['Two dog jump on one another on a grassy area cover in leaf .',
#   'Two dog play with each other in the leaf .',
#   'Two puppy be play in the leaf .',
#   'two puppy play with each other surround by a bunch of leaf',
#   'Two small dog , light and dark colored , fight on leaf .'],
#  '3354883962_170d19bfe4.jpg': ['A dog run in the snow .',
#   'An off-white dog have his mouth open as he bound through a fenced-in snowy area .',
#   'A white dog run past a fence on a snowy day .',
#   'A white dog with a black collar run in the snow .',
#   'A white poodle be run in the snow , near a chain link fence .'],
#  '2346401538_f5e8da66fc.jpg': ['A woman hold onto a camera smile at the camera .',
#   'A woman with a blue hat and blue and red jacket set up a camera on a tripod .',
#   'A woman with a camera on a tripod be smile for another camera .',
#   'People at a photo shoot .',
#   'A woman in blue be operate a camera in front of two other woman .'],
#  '3605676864_0fb491267e.jpg': ['A boy with a beach ball behind him play in a pool',
#   'A young boy play around in a jacuzzi .',
#   'child play in an inflatable pool .',
#   'A boy laugh as he swim in a pool .',
#   'Two child be in a pool with a beach ball float nearby .'],
#  '3658427967_6e2e57458d.jpg': ['A boy in a swimsuit jump into water .',
#   'A boy in blue camo pants jump into water .',
#   'A boy be about to jump into the water .',
#   'A boy jump into the water at a beach .',
#   'A young man leap into the water .'],
#  '2868575889_2c030aa8ae.jpg': ['A man in an orange shirt flip his skateboard on a suburban street .',
#   'A man in a red shirt be perform an aerial trick with a skateboard on a sidewalk .',
#   'A skateboarder in the air above his board on a residential street .',
#   'A young man jump up off his skateboard on a street in front of a house .',
#   'A guy be wear a red shirt and do a aerial flip with his skateboard .'],
#  '3494394662_3edfd4a34c.jpg': ['A closeup of an elderly man .',
#   'A man pose outdoors .',
#   'A man with a red collar and gray beard look at the camera .',
#   'An old man wear a black jacket stand outside .',
#   'Beard man in fleece jacket smile for a picture , the background be blurry'],
# ...
#   'A man in a blue suit read a paper while smoke next to a marble building .',
#   'A man be stand up , read a newspaper , and smoke a cigar .',
#   'A man smoke a cigar read a paper in a city',
#   'A man stand by a building corner and read a newspaper .'],
#  '3187492926_8aa85f80c6.jpg': ['A man dive into a clear blue lake .',
#   'A man in black bathe trunk dive into water .',
#   'A man in black short be dive into a rocky pool .',
#   'A man in black swim trunk dive into the water',
#   'A person be dive into clear blue water .'],
#  '3673165148_67f217064f.jpg': ['A brown and white dog be stand in shallow water on a beach near a large rock outcrop .',
#   'A brown and white dog on a beach .',
#   'A dog stand on a beach .',
#   'A dog stand on a beach with a large rock behind him .',
#   'An unusual look dog be stand in front of a beautiful backdrop .'],
#  '270724499_107481c88f.jpg': ['A dog with a blue ball run in a field .',
#   'a small tan dog run on the grass with a ball in his mouth',
#   'Dog run towards camera with a ball in its mouth .',
#   'small dog run in the grass with a toy in its mouth',
#   'A dog be run with a colorful ball .'],
#  '2182488373_df73c7cc09.jpg': ['A city street with two lady that have shop bag in their hand with a crowd behind them .',
#   'A woman in a hat hold a handbag smile away from another woman wear sunglasses and hold a shop bag .',
#   'People be stand on the Hollywood walk of fame .',
#   'two old woman walk down a busy street with shop bag',
#   'Two woman dress in leather be stand on a city street .'],
#  '2421446839_fe7d46c177.jpg': ['A dog jump up towards a woman in a car , while another dog be outside a car .',
#   'An orange dog and a little white dog with black spot be next to a white car .',
#   'A small black and white dog jump at a woman in a white jeep while a golden dog follow beside them .',
#   "A small dog jump by a car to reach a lady 's face while another dog watch .",
#   'White and black dog jump at someone through car window .'],
#  '2603792708_18a97bac97.jpg': ['A bunch of person on a beach at sunset .',
#   'Two person be walk towards a group of person on a beach at sunset .',
#   'Two person walk along a beach at sunset towarn a group of person .',
#   'Two person walk along the shore at sunset .',
#   'Two person walk on a beach at sunset .'],
#  '2822290399_97c809d43b.jpg': ['A small white dog have on a leash and be walk next to a fence .',
#   'A white dog be walk down a dirt road .',
#   'A white dog run along a path , trail a leash .',
#   'A white dog with a loose leash be on a dirt road',
#   'A white puppy walk down a dirt path trail his leash on the ground behind him .'],
#  '1332722096_1e3de8ae70.jpg': ['Three woman stand on a city street .',
#   'Three woman walk down a street .',
#   'Two girl and a woman walk on a sidewalk',
#   'Two girl in bright green boot and a woman be together .',
#   'Two young lady in green boot be walk through an urban area while an old lady wear black shoe follow them .'],
#  '3694064560_467683205b.jpg': ['a man talk to a boy .',
#   'An old man be speak to a boy while both be sit .',
#   'Two boy talk while wear unique outfit .',
#   'Two male in period costume be have a conversation .',
#   'Two person sit on bench and look at each other .'],
#  '3263395801_5e4cee2b9e.jpg': ['A dirt biker in a forest .',
#   'A dirt biker ride his motocycle through the wood .',
#   'A motocross bike be be ride along a woodland path .',
#   'A motorcyclist navigate a forest trail .',
#   'A person ride a motorbike on a dirt path surround by tree .'],
#  '3701291852_373ea46bb6.jpg': ['A boy and a girl be stand on the edge of a lake at sunset .',
#   'Two child be walk by a pond',
#   'Two figure be walk by a pond .',
#   'Two person be silhouette against a lake reflect a paint sky .',
#   'Two person silhouette against a lake at sunset .'],
#  '2343525685_3eba3b6686.jpg': ['A dark-haired man wear a brown shirt be free-climb a gray stone wall .',
#   'a man hold on to a rock wall',
#   'A man scale a rock climb wall .',
#   'A man struggle to climb a rock wall .',
#   'A man with glasses climb a rock wall .'],
#  '416106657_cab2a107a5.jpg': ['A fluffy white dog run through the wood with his ear flap in a breeze .',
#   'A small white dog be run across a grassy field .',
#   'A white dog run in the grass ,',
#   'A white dog wear a red harness run through the wood .',
#   'A little white dog wear the red collar be run in the grass .'],
#  '387830531_e89c192b92.jpg': ['a brown dog about to jump on a small black and tan dog',
#   'Large dog play with small dog',
#   'Two dog be play together outside .',
#   'Two dog play in the grass with an adult nearby .',
#   'Two dog play with each other .'],
#  '2892995070_39f3c9a56e.jpg': ['A black dog be run along a beach beside a brown dog in midair catch a stick in its mouth .',
#   'A black dog run on the shore while a light brown dog jump up to catch a stick .',
#   'A brown dog leap into the air next to a black dog on a sandy bay .',
#   'On a beach , black and brown dog run , brown dog jump .',
#   'Two dog be play together'],
#  '3432550415_e7b77232de.jpg': ['A boy stand on railing',
#   'A boy stand on a rail with his arm outstretched .',
#   'An inline skater be attempt a trick in a long metal rail behind a large structure .',
#   'A skateboarder be ride a skateboard along a metal railing in front of a concrete building .',
#   'A boy be do a trick on a rail next to an overpass .'],
#  '3564312955_716e86c48b.jpg': ['A closeup of a young child wear a pink bathe suit lay in shallow water at a beach .',
#   'A little girl smile as she lay on her side in the water .',
#   'a smile toddler in a pink swimsuit be lay in the water .',
#   'A young dark haired girl in a pink and white swimsuit smile as she lie in three inch deep water .',
#   'Little girl in swimsuit lie on stomach in water , smile at camera .'],
#  '3238951136_2a99f1a1a8.jpg': ['A man in swim trunk be stand against some rock .',
#   'A man wear flower swim trunk be stand near large mossy rock .',
#   'A man wear red short be hold onto rock beside the water .',
#   'Man in red shoe and red and white print short pose in front of rock by water .',
#   'Man pose by a natural pool .'],
#  '3595643050_d312e4b652.jpg': ['A dog catch a ball .',
#   'A dog jump up in the air next to a white house .',
#   'A white dog be stand on its hind leg with a ball in its mouth .',
#   'A yellow dog stand on his hind leg .',
#   'Yellow dog stand on hind leg with ball in mouth , building in background .'],
#  '3139876823_859c7d7c23.jpg': ['A downhill skier in black catch a tiny bit of air',
#   'A man ski down a snowy hill .',
#   'A skier about to go down a mountain .',
#   'A skier be on a snow cover hill .',
#   'A skier be aim downhill , overlook a wooded area .'],
#  '3473264983_67917a931f.jpg': ['A bunch of guy in black play paintball .',
#   'a group of person wear body Armor while fight with paintball gun .',
#   'A paintball team shoot',
#   'Some person play paintball .',
#   'Speed ball paintball team start the first round .'],
#  '2994179598_a45c2732b5.jpg': ['A man in a Miami basketball uniform look to the right',
#   'a man wear a orange jersey .',
#   'A Miami basketball player look off in the distance .',
#   'A man shirt be orange and have a United State flag patch on the shoulder .',
#   'The Miami basketball player be look .'],
#  '491405109_798222cfd0.jpg': ['A girl pose with her head upside down .',
#   'A little girl hang her head upside down .',
#   'A small girl be do a handstand while smile',
#   "A upside down girl 's face .",
#   'a young girl smile with her head upside down'],
#  '3115174046_9e96b9ce47.jpg': ['A skateboarder cast a shadow jump down stair .',
#   'A skateboarder fly off the stair .',
#   'a skateboarder jump a staircase .',
#   'A skateboarder perform a kickflip over short stair .',
#   'Skateboarder jump down a short flight of stair in a dim light warehouse .'],
#  '3631986552_944ea208fc.jpg': ['A surfer catch a big wave in the ocean .',
#   'A surfer go through a wave .',
#   'A surfer in water and foam .',
#   'A surfer ride the crash wave .',
#   'A surfer catch a big wave but stay on his board .'],
#  '3350786891_6d39b234e9.jpg': ['A group of dark skinned child be sit beside a red metal container .',
#   'A group of kid sit against a large red dumpster .',
#   'a group of person sit outside in the dirt on the ground .',
#   'A large group of person sit near a ship container .',
#   'Two sub Saharan African girl in purple dress sit on the ground .'],
#  '3062173277_bfb5ef4c45.jpg': ['A group of person be row a boat in a contest .',
#   'A row team race forward in competition with the motivation of their leader in front of a boat .',
#   'Boat number 5 have several man with life jacket paddle the water .',
#   'People in orange vest be row with great effort .',
#   'Several person be row a boat while be cheer on by a person with a drum'],
#  '3108197858_441ff38565.jpg': ['A group of child be raise their hand in the air .',
#   'A group of kid sing and put their hand in the air',
#   'Little kid stand together and raise their hand in the air .',
#   'Little kid with their hand in the air',
#   'Some child be raise their hand and clap .'],
#  '1224851143_33bcdd299c.jpg': ['A boy eat with a spoon .',
#   'A little boy hold a spoon up to his mouth .',
#   'A little boy be eat his food off of a spoon while sit on a patio .',
#   'A small child dress in green be eat with a spoon .',
#   'A young child hold a spoon to its mouth while sit in a chair .'],
#  '3458559770_12cf9f134e.jpg': ['A biker with a blue jacket , black pants , and white helmet drive on dirt while person watch .',
#   'A person on a bmx bike .',
#   'Person in blue jacket on a bike on a dirt course with person look from behind a red and white barrier .',
#   'A biker in blue be go around a corner .',
#   'A motocross rider wear blue and black pants .'],
#  '3425835357_204e620a66.jpg': ['A boy do a handstand in a yellow shirt',
#   'A boy be brake dance as a crowd watch .',
#   'A man be stand on his hand on a sidewalk while others watch .',
#   'A man be stand on his hand with lot of person around him .',
#   'A person do a handstand in front of others .'],
#  '3214885227_2be09e7cfb.jpg': ['A man boat along a river near the shore .',
#   'A man paddle a kayak along the shore of a river .',
#   'A person be ride in a canoe on a lake next to green tree .',
#   'A person be wade through a river near an erode embankment .',
#   'A single person row a small boat on a lake .'],
#  '2854207034_1f00555703.jpg': ['A man be lie on the grass next to a shop cart .',
#   'A person be lie on the green grass and there be a small cart next to them .',
#   'A person lie on the grass with a shop cart nearby .',
#   'There be a shop cart and a person lay on the ground in a green field of grass .',
#   'There be one person lie in a large , green field .'],
#  '2167644298_100ca79f54.jpg': ['A man dress in black wear a hat and glasses in front of a red wall .',
#   'A man in a black hat stand in front of a red wall .',
#   'A man wear all black and a black hat be smile .',
#   'A man with a hat , glasses , jewelry and a jacket stand against an orange wall .',
#   'There be a man with glasses and a hat wear a black suit jacket indoors .'],
#  '241346971_c100650320.jpg': ['A football player in blue and one in red play in a game .',
#   'A Sooner football player move quick on the field as another player run .',
#   'A guy in a blue and white jersey be run , and a guy in a red and white jersey be fall .',
#   'Two player , on opposite team , be in the middle of a football game , while others watch .',
#   'Two man play football .'],
#  '1386964743_9e80d96b05.jpg': ['a boy be play with a camera whilst stand on a dirt track .',
#   'A child in a field .',
#   'a kid stand in the middle of a dirt road',
#   'A young child stand in a path in a field of sunflower .',
#   'Small child with black hair stand in car track near sunflower .'],
#  '3397220683_4aca010f86.jpg': ['A golden retreiver stand outside in the snow with a person stand with ski and pole .',
#   'A man and a dog outside in a snow storm .',
#   'A person be stand on ski in the snow with a dog .',
#   'Person with ski and a dog be stand in the snow .',
#   'A man be ski in the snow with a large brown dog .'],
#  '2473791980_805c819bd4.jpg': ['a lone parasailer surf in the ocean wear a black swimsuit .',
#   'A man be kite surf away from the camera .',
#   'A man be sky surf on the water .',
#   'A man waterskis while attach to a parachute .',
#   'A waterskier cut through the blue water with sailboat in the background .'],
#  '241345844_69e1c22464.jpg': ['A coach speak to a football player while everyone watch .',
#   'A football player from Ou talk to a coach about a game .',
#   'A football player be talk to his coach .',
#   'The coach official and football player be talk in front a crowd and other team member .',
#   'A coach talk it over with his quarterback during a timeout .'],
#  '3256043809_47258e0b3e.jpg': ['a brown and white dog be sniff the snow cover ground .',
#   'A brown and white dog walk in the snow near a fence .',
#   'A brown & white greyhound dog sniff the snow .',
#   'A lean white and brown dog make its way through a patch of snow .',
#   'A slender dog check out a snowy patch of land .'],
#  '2351479551_e8820a1ff3.jpg': ['A boy wear blue short be do a back flip in the air under a tree .',
#   'A man in midair do a flip .',
#   'a young man jump a back flip off of a concrete wall .',
#   'Man with blue pants flip in the air .',
#   'A boy wear blue pants be in the midst of a back flip .'],
#  '3514179514_cbc3371b92.jpg': ['A baseball player attempt to catch a ball while another run towards the base .',
#   'A baseball player catch the ball while the batter reach the base .',
#   'A baseman try to catch a ball while a runner try to make the base in a community game .',
#   'An umpire in a baseball game crouch to catch a ball while an oppose team member run to homebase .',
#   'Two child be play baseball'],
#  '1119015538_e8e796281e.jpg': ['A little tan dog with large ear run through the grass .',
#   'A playful dog be run through the grass .',
#   'A small dog ear stick up as it run in the grass .',
#   'A small dog be run across a lawn .',
#   'this be a small beige dog run through a grassy field'],
#  '3727752439_907795603b.jpg': ['a large woman put her sunglasses on .',
#   'A woman in a black dress hold sunglasses .',
#   'a woman wear a black and white outfit while hold her sunglasses .',
#   'A lady be hold her glasses .',
#   'A woman with blond hair hold her sunglasses .'],
#  '3430607596_7e4f74e3ff.jpg': ['A boy in a red suit play in the water .',
#   'A boy in a red swimsuit jump into the water to join two person .',
#   'A boy take a fly leap into the water .',
#   'A boy in red short jump into the water to join other person .',
#   'A boy wear red short be jump into a river as other child swim .'],
#  '3259666643_ae49524c81.jpg': ['A basketball player perform a layup .',
#   'A boy in a blue basketball uniform , number 13 and a boy in a white basketball uniform , number 23 jump for the ball .',
#   'A man in a white uniform jump while hold a basketball as another in blue block him .',
#   'Basketball player wear a white , number 23 jersey jump up with the ball while guard by number 13 on the opposite team .',
#   'A man in white be play basketball against a man in blue .'],
#  '2623930900_b9df917b82.jpg': ['A man who have a gray beard and gray hair laugh while wear a purple shirt .',
#   'A man with a bushy beard and pink shirt be smile .',
#   'A man with disheveled hair and facial hair in a crowd of person be smile .',
#   'A man with poofy gray hair laugh',
#   'An old man with white long hair and a white long beard .'],
#  '3490736665_38710f4b91.jpg': ['A big dog stand on his hand leg as tennis ball be throw his direction .',
#   'A brown and white dog in front of a shed overwhelmed by the onslaught of tennis ball .',
#   'A brown and white dog stand in front of a wooden building while tennis ball fly through the air .',
#   'A dog jump for several tennis ball throw at him .',
#   'A dog stand on his hind leg amid a shower of tennis ball .']}
